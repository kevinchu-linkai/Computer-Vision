# %% [markdown]
# # CSCI-UA 0480-042 Computer Vision
# ## Homework 3

# %% [markdown]
# Enter your name and NetID below.
#
# #### Name: Kevin Chu
# #### NetID: kc4624

# %% [markdown]
# The main goals of this assignment include:
#
# 1. Giving an introduction to Mask-RCNN
# 2. Training the predictors for a given dataset
# 3. Finetuning the entire network for the same dataset
#
# Also accompanying each part, there are a few questions (**12 questions in total**) -- 11 mandatory + 1 extra credit. The first 11 questions are worth 100 points and the extra credit question is worth 10 points.
#
# Please give your answers in the space provided. This homework has a mix of conceptual and coding questions. You can quickly navigate to coding questions by searching (Ctrl/Cmd-F) for `TODO:`.

# %% [markdown]
# # 1. Introduction to Mask-RCNN

# %% [markdown]
# [Mask-RCNN](https://arxiv.org/pdf/1703.06870.pdf) is a network used for instance segmentation. Instance segmentation can be thought of as a hybrid of semantic segmentation and object detection. In other words, we don't want to just find the bounding boxes for each object in our image, we're also interested in finding the segmentation mask of *each object instance*.
#
# ![Instance Segmentation as a Hybrid of Semantic Segmentation and Object Detection](../shared/HW3/img/instance_segmentation.png)
#
# Image Credits: https://towardsdatascience.com/single-stage-instance-segmentation-a-review-1eeb66e0cc49

# %% [markdown]
# Mask-RCNN is built on top of Faster-RCNN, which is a network used for object detection. Faster-RCNN has 2 outputs for each candidate object (Region of Interest or RoI) - a class label and a bounding box offset. Mask-RCNN adds a third branch to Faster-RCNN for predicting segmentation masks on each RoI.

# %% [markdown]
# We'll first briefly go over Faster-RCNN. Faster-RCNN has 2 stages:
#
# 1. **Region Proposal Network (RPN):** Given the image, it proposes candidate object bounding boxes. Previous object detection models such as RCNN and Fast-RCNN handled this separately from the CNN model. Faster-RCNN takes a different approach -- it integrates these two components into the same network to achieve speedup.
# 2. **Fast-RCNN:** This stages takes each candidate RoI and extracts features from the image feature vector using RoIPool. Using these RoI features, it performs classification and bounding box regression.

# %% [markdown]
# ![Mask-RCNN framework for instance segmentation](../shared/HW3/img/mask_rcnn_architecture.png)

# %% [markdown]
# Mask-RCNN has the same 2-stage procedure, but in the 2nd stage, instead of just predicting the classification label and the bounding box offset, it predicts **in parallel** a binary mask for each RoI.
#
# Mask-RCNN relies on a pretrained network (called the "backbone" in the paper) to extract features from the image. These features are fed into the Region Proposal Network (RPN) to generate candidate RoIs. For each RoI candidate, a fixed size RoI feature vector is generated using an RoIAlign layer. This RoI feature map is then provided to the classifier, bounding box predictor and the segmentation mask to generate the final output.

# %% [markdown]
# ## Question 1 [10%]
#
# Training uses a multi-task loss function. What are the three components in this loss function? Is the loss computed per image or per RoI?

# %% [markdown]
# #### Answer :
# Localization Loss (L_loc): This component measures how accurately the model predicts the bounding box coordinates for each Region of Interest (RoI).
#
# Classification Loss (L_cls): This component measures the accuracy of the class predictions for each RoI. It's essentially a classification loss that evaluates whether the model correctly identifies the object category or class within each RoI.
#
# Mask Prediction Loss (L_mask): This component is specific to instance segmentation tasks (e.g., Mask R-CNN). It measures the accuracy of the pixel-wise mask predictions for each RoI.
#
# In the case of object detection and instance segmentation using models like Faster R-CNN or Mask R-CNN, the loss is computed per RoI.

# %% [markdown]
# ## Question 2 [5%]
# [This blog post](https://lilianweng.github.io/lil-log/2017/12/31/object-recognition-for-dummies-part-3.html) by Lilian Weng gives a nice overview of the object detection (RCNN type) networks. In the blog post, it is mentioned that Mask-RCNN uses RoIAlign instead of RoIPool. Explain briefly in 3-4 lines why this is being done.

# %% [markdown]
# #### Answer :
# RoIAlign eliminates the harsh quantization by utilizing calculations like x/16x/16 instead of [x/16][x/16], allowing the extracted features to be more accurately aligned with the input pixels. This precision is essential for tasks like pixel-level segmentation, which require a higher degree of alignment than what RoIPool can provide

# %% [markdown]
# ## Question 3 [5%]
# What are the different backbones explored in the Mask-RCNN paper? They are denoted in the paper using network-depth-features nomenclature. What is the advantage of using a ResNet-FPN backbone over a ResNet-C4 backbone for feature extraction?

# %% [markdown]
# #### Answer :
# In the Mask R-CNN paper, the backbones explored include ResNet and ResNeXt networks with depths of either 50 or 101 layers. The backbones are denoted using the nomenclature network-depth-features. For instance, the original implementation of Faster R-CNN with ResNets extracted features from the final convolutional layer of the 4th stage, referred to as C4. Thus, a ResNet-50 backbone in this configuration is denoted as ResNet-50-C4.
#
# The paper also explores the use of a Feature Pyramid Network (FPN) as a more effective backbone. FPN is a top-down architecture with lateral connections, building an in-network feature pyramid from a single-scale input. Using a ResNet-FPN backbone for feature extraction with Mask R-CNN is reported to offer excellent gains in both accuracy and speed.
#
# Generally, FPN architectures are known to improve performance in object detection tasks by efficiently using multi-scale feature maps, which is likely a key factor in their advantages over C4 backbones.

# %% [markdown]
# # 2. Training the Predictors for a New Dataset

# %% [markdown]
# In this section, we'll start with a pretrained Mask-RCNN model that uses Resnet-50-FPN as the backbone. This model was trained on MS-COCO dataset which is widely used for multiple vision tasks such as object detection, instance segmentation, etc.
#
# MS-COCO has 91 classes (90 for objects + 1 for background). Some sample objects in the dataset include `person`, `car`, `bicycle`, `knife`, `train`, etc.
#
# Along with this homework file, we have also provided another sample dataset (we'll refer to it as the [Nature dataset](https://towardsdatascience.com/custom-instance-segmentation-training-with-7-lines-of-code-ff340851e99b)). It isn't a standard dataset, but it's small enough (600 train + 200 test images) and allows us to easily demo finetuning a pretrained Mask-RCNN model. This dataset contains only 2 classes - `squirrel` and `butterfly`.
#
# Our goal in part2 and part3 of this assignment is to take the pretrained Mask-RCNN model and finetune/train it for this dataset. However, here in part2, instead of finetuning the entire network, we'll train only the final layers.
#
# In Homework 2, we've shown how one could feed data into the network using `Dataset`s and `DataLoader`s. We'll use the same strategy here for finetuning the model.
#
# We've based this homework on this [PyTorch tutorial on Object Detection Finetuning](https://pytorch.org/tutorials/intermediate/torchvision_tutorial.html).

# %% [markdown]
# ## Question 4 [25%]
#
# Complete the TODO section in below cell. Specifically:
#
# 1. Read image height, width and polygon shapes data from the JSON file.
# 2. Generate 2D masks from the polygon points. You can follow this idea: https://stackoverflow.com/a/3732128
# 3. Generate the bounding boxes from the mask data. Assume that the bounding box is a rectangle with the smallest area enclosing the mask.
#
# You may find this json schema useful:
# ```
# {
#    "shapes": [ # list of object instances; masks are represented as polygons
#        ## data for instance1
#        {
#            "label": "" # label for instance1
#            "points": [] # 2d list of polygon points [(x1, y1), (x2, y2), ..]
#        },
#        ## data for instance2
#        {
#            "label": []
#            "points": []
#        },
#
#        ..
#        ..
#    ],
#    "imagePath": ""
#    "imageData" : ""
#    "imageHeight": <integer>
#    "imageWidth": <integer>
# }
# ```

# %%
# Alternatively, you could also uncomment the line below to see a sample json file
#!cat '../shared/data/HW3/nature/train/s (3).json'

# %%
import numpy as np
import torch
import torchvision

import json # for reading from json file
import glob # for listing files inside a folder
from PIL import Image, ImageDraw # for reading images and drawing masks on them.


# Create a custom dataset class for Nature
# dataset subclassing PyTorch's Dataset class
class NatureDataset(torch.utils.data.Dataset):
    def __init__(self, root, transforms):
        self.transforms = transforms
            
        # Load all image files, sorting them to
        # ensure that they are aligned with json files
        imgs = glob.glob(root + '/*.jpg')
        imgs += glob.glob(root + '/*.png') # some images are in png format
        self.imgs = sorted(imgs)
        
        # Mask data is stored in a json file
        masks = glob.glob(root + '/*.json')
        self.masks = sorted(masks)

        # Each image can have multiple object instances, and each
        # instance is associated with either of these 2 labels.

        # Need to convert str-labels to ids. So we'll use 
        # this label-to-index mapping.
        # Note: we can't start from 0 because 0 is restricted
        # to the "background" class
        self.label_to_id = {'squirrel': 1, 'butterfly': 2}

        # Check if any files were found
        if len(self.imgs) == 0 or len(self.masks) == 0:
            raise RuntimeError("No images or JSON files found in the provided directory.")
            
    def __getitem__(self, idx):
        # Have already aligned images and JSON files; can now
        # simply use the index to access both images and masks
        img_path = self.imgs[idx]
        mask_path = self.masks[idx]
        
        # Read image using PIL.Image and convert it to an RGB image
        img = Image.open(img_path).convert("RGB")
        
        # TODO: Read image height, width and mask data from
        # the JSON file
        with open(mask_path, 'r') as fp:
            # TODO: Using json library read the dictionary
            # from the fp
            json_dict = json.load(fp)
            
            # TODO:
            height = json_dict['imageHeight']
            
            # TODO:
            width = json_dict['imageWidth']
            
            # TODO:
            poly_shapes_data = json_dict['shapes']
        
        # TODO: Each image can have multiple mask instances.
        # Using the polygon points, generate the 2d-mask
        # using PIL's ImageDraw.polygon
        masks = []
        labels = []
        for shape_data in poly_shapes_data:
            polygon_points = [tuple(point) for point in shape_data['points']]
            
            # TODO: Using Image.new() create an image of size (width, height)
            # and fill it with 0s.
            mask_img = Image.new('L', (width, height), 0)
            
            # TODO: Draw the mask on the base image we just created
            ImageDraw.Draw(mask_img).polygon(polygon_points, outline=1, fill=1)

            mask = np.array(mask_img)
            masks.append(mask)

            label = shape_data['label']
            labels.append(label)
        
        # Each mask instance also has an associated label which is str-type
        # Convert the str into an int using the mapping we created in __init__
        labels = [self.label_to_id[label] for label in labels]
        
        # TODO: Generate the bounding boxes for each instance
        # from the 2d masks
        num_objs = len(masks)
        boxes = []
        for i in range(num_objs):
            # TODO: Use np.where() to find where mask[i] == True.
            # pos will be a 2d-list of indices
            pos = np.where(masks[i])
            
            # In pos, find the min x- and y- indices;
            # max x- and y- indices. This will give us our box bounds.
            
            # TODO:
            xmin = np.min(pos[1])
            
            # TODO:
            xmax = xmax = np.max(pos[1])
            
            # TODO:
            ymin = np.min(pos[0])
            
            # TODO:
            ymax = np.max(pos[0])
            
            boxes.append([xmin, ymin, xmax, ymax])

        # Convert everything into a torch.Tensor
        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        labels = torch.as_tensor(labels, dtype=torch.int64)
        masks = torch.as_tensor(masks, dtype=torch.uint8)

        image_id = torch.tensor([idx])
        area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])

        # Assume all instances are not crowd
        iscrowd = torch.zeros((num_objs,), dtype=torch.int64)

        target = {}
        target["boxes"] = boxes
        target["labels"] = labels
        target["masks"] = masks
        target["image_id"] = image_id
        target["area"] = area
        target["iscrowd"] = iscrowd
        
        # Apply transforms
        if self.transforms is not None:
            img, target = self.transforms(img, target)

        return img, target

    
    def __len__(self):
        return len(self.imgs)

# %% [markdown]
# Having implemented our `NatureDataset` class, let's create the `Dataset` and the `DataLoader` objects. Note that we're not using `torchvision.transforms`, instead we're using transforms provided in a separate script in this directory called `transforms.py`.

# %%
import transforms as T

def get_transform(train):
    transforms = []
    transforms.append(T.ToTensor())
    if train:
        transforms.append(T.RandomHorizontalFlip(0.5))
    return T.Compose(transforms)

# use our dataset and defined transformations
dataset = NatureDataset('../shared/data/HW3/nature/train', get_transform(train=True))
dataset_test = NatureDataset('../shared/data/HW3/nature/test', get_transform(train=False))

import utils

# define training and validation data loaders
data_loader = torch.utils.data.DataLoader(
    dataset, batch_size=2, shuffle=True,
    collate_fn=utils.collate_fn)

data_loader_test = torch.utils.data.DataLoader(
    dataset_test, batch_size=1, shuffle=False,
    collate_fn=utils.collate_fn)

# %% [markdown]
# Now let's visualize one image from our dataset.

# %%
import matplotlib.pyplot as plt

img, targets = dataset[506]

# np.transpose docs: https://numpy.org/doc/stable/reference/generated/numpy.transpose.html
# img is a PyTorch tensor, can convert it to a NumPy tensor by calling .numpy() on it.
plt.imshow(np.transpose(img.numpy(), (1, 2, 0)));
# Out:
# /tmp/ipykernel_93/2904297283.py:118: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:261.)
#   masks = torch.as_tensor(masks, dtype=torch.uint8)

# %% [markdown]
# And here's the corresponding mask.

# %%
plt.imshow(targets['masks'].numpy().squeeze(), interpolation='none')

# %% [markdown]
# We'll be training the final layers of the pretrained Mask-RCNN model (with Resnet-50-FPN backbone) available in the `torchvision` package. So let's download the model:

# %%
model_p2 = torchvision.models.detection.maskrcnn_resnet50_fpn(pretrained=True)
# Out:
# /opt/conda/envs/csciua-0480042-fall/lib/python3.8/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/envs/csciua-0480042-fall/lib/python3.8/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MaskRCNN_ResNet50_FPN_Weights.COCO_V1`. You can also use `weights=MaskRCNN_ResNet50_FPN_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %% [markdown]
# ## Question 5 [5%]
#
# Recall what we said earlier: For training for the new dataset, we need to modify its box predictor (FastRCNNPredictor) and its mask predictor (MaskRCNNPredictor) to match with the new dataset. Complete the code cell below.
#
# You may find these docs for `FastRCNNPredictor` and `MaskRCNNPredictor` useful:
#
# ![FastRCNNPredictor Docs](../shared/HW3/img/FastRCNNPredictor_docs.png)
# ![MaskRCNNPredictor Docs](../shared/HW3/img/MaskRCNNPredictor_docs.png)

# %%
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.models.detection.mask_rcnn import MaskRCNNPredictor

# Our new dataset has 3 classes: butterfly, squirrel and background
num_classes = 3

# Get number of input features for the classifier
in_features = model_p2.roi_heads.box_predictor.cls_score.in_features

# TODO: replace the pre-trained head with a new one
model_p2.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

# Get number of input features for the mask predictor
in_features_mask = model_p2.roi_heads.mask_predictor.conv5_mask.in_channels
hidden_layer = 256

# TODO: replace the mask predictor with a new one
model_p2.roi_heads.mask_predictor = MaskRCNNPredictor(in_features_mask, hidden_layer, num_classes)

# %% [markdown]
# Training these layers can take several minutes on a CPU, so we've provided GPUs to make this faster. It should take ~5 mins to run the training in Q7. But before that, we want to ensure that PyTorch is able to access the GPU by printing the device PyTorch is currently (prints `cuda` if it's using a GPU, otherwise it prints `cpu`).
#
# Now we want to freeze all the layers below these predictors. We can do this by setting the `.requires_grad` attribute of the parameters we want to freeze to `False`. Read more about `requires_grad` from [this PyTorch page on Autograd mechanics](https://pytorch.org/docs/stable/notes/autograd.html#excluding-subgraphs-from-backward).
#
# In order to do the computation on a GPU, we have to move the model from main memory to GPU memory. This can be done by simply calling `.to(device)` on the model. See [the docs](https://pytorch.org/docs/stable/generated/torch.nn.Module.html#torch.nn.Module.to) for more information.

# %% [markdown]
# ### Note : Make sure the below prints `Using : cuda` before proceeding further. If it doesn't print cuda , make sure you are in the GPU profile of the server. To start the server in GPU profile, shutdown the current server and restart the server by selecting the GPU option.

# %%
import itertools

# Freeze model and move it to device
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
print("Using : ", device)

for param in model_p2.parameters():
    param.requires_grad = False

pred_params = itertools.chain(
    model_p2.roi_heads.mask_predictor.parameters(),
    model_p2.roi_heads.box_predictor.parameters()
)

for param in pred_params:
    param.requires_grad = True

model_p2 = model_p2.to(device)
# Out:
# Using :  cuda

# %% [markdown]
# We were able to verify that PyTorch is able to access a GPU. Now let's see the layers inside the `model_p2.roi_heads` to understand what we have modified here (we just modified `box_predictor` and `mask_predictor`). You could also verify the output below from figure 4 in the Mask-RCNN paper. You'll notice that it's the exact same network on the right part of that figure.

# %% [markdown]
# We can use below command to check what are the GPU devices that are available to us and their current memory usage. Having a GPU in the list doesn't mean we can simply use it for training. We need to have proper CUDA drivers and compatible versions of pytorch/torchvision libraries. We have made sure that the versions are compatible and one is able to use GPU without and additional changes.

# %%
# !nvidia-smi
# Out:
# Mon Nov 20 22:29:51 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.182.03   Driver Version: 470.182.03   CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P0    26W /  70W |    822MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
model_p2.roi_heads
# Out:
# RoIHeads(
#   (box_roi_pool): MultiScaleRoIAlign(featmap_names=['0', '1', '2', '3'], output_size=(7, 7), sampling_ratio=2)
#   (box_head): TwoMLPHead(
#     (fc6): Linear(in_features=12544, out_features=1024, bias=True)
#     (fc7): Linear(in_features=1024, out_features=1024, bias=True)
#   )
#   (box_predictor): FastRCNNPredictor(
#     (cls_score): Linear(in_features=1024, out_features=3, bias=True)
#     (bbox_pred): Linear(in_features=1024, out_features=12, bias=True)
#   )
#   (mask_roi_pool): MultiScaleRoIAlign(featmap_names=['0', '1', '2', '3'], output_size=(14, 14), sampling_ratio=2)
#   (mask_head): MaskRCNNHeads(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#     (1): Conv2dNormActivation(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#     (2): Conv2dNormActivation(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#     (3): Conv2dNormActivation(
#       (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): ReLU(inplace=True)
#     )
#   )
#   (mask_predictor): MaskRCNNPredictor(
#     (conv5_mask): ConvTranspose2d(256, 256, kernel_size=(2, 2), stride=(2, 2))
#     (relu): ReLU(inplace=True)
#     (mask_fcn_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#   )
# )

# %% [markdown]
# ## Question 6 [10%]
# We just printed the head architecture. From the above output, list all the layers we're training along their names.
#
# For example, if we're training mask_fcn1 of mask_head you'll specify:
#
# `mask_head.mask_fcn1`: 2d-Conv layer with 256 input channels, 256 output channels and kernel size = (2, 2).
#
# Note: We're **only** asking for layers with trainable parameters.

# %% [markdown]
# #### Answer :
# Box Head Layers:
#      box_head.fc6: Linear layer with 12544 input features and 1024 output features.
#      box_head.fc7: Linear layer with 1024 input features and 1024 output features.
#
# Box Predictor Layers:
#     box_predictor.cls_score: Linear layer with 1024 input features and 3 output features (for class scores).
#     box_predictor.bbox_pred: Linear layer with 1024 input features and 12 output features (for bounding box regression).
#
# Mask Head Layers (MaskRCNNHeads):
# Each of the Conv2dNormActivation layers (four in total) in mask_head:
#     mask_head.0.0: Conv2d layer with 256 input channels, 256 output channels, and a kernel size of (3, 3).
#     mask_head.1.0: Conv2d layer with 256 input channels, 256 output channels, and a kernel size of (3, 3).
#     mask_head.2.0: Conv2d layer with 256 input channels, 256 output channels, and a kernel size of (3, 3).
#     mask_head.3.0: Conv2d layer with 256 input channels, 256 output channels, and a kernel size of (3, 3).
#
# Mask Predictor Layers:
#         mask_predictor.conv5_mask: ConvTranspose2d layer with 256 input channels, 256 output channels, and a kernel size of (2, 2).
#         mask_predictor.mask_fcn_logits: Conv2d layer with 256 input channels, 3 output channels (for mask predictions), and a kernel size of (1, 1).

# %% [markdown]
# Both the dataloaders and model have been prepared for training. All that remains is to set an optimizer and a learning rate scheduler. When we create an optimizer, we have to provide it the list of trainable parameters.

# %%
# Declare optimizer and lr
params = [p for p in model_p2.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, lr=0.005, momentum=0.9, weight_decay=0.0005)
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                                step_size=3,
                                                gamma=0.1)

# %% [markdown]
# ## Question 7 [10%]
#
# How many trainable parameters are we passing to the optimizer?
#
# Here's an example to calculate # of trainable parameters in a fully connected layer with:
# 1. an additive bias
# 2. in_channels = 1024
# 3. out_channels = 10
#
# The number of trainable parameters here will be 1024\*10 + 10 = 10250.

# %% [markdown]
# #### Answer :
# 16,534,546
#
# Box Head Layers:
#
# box_head.fc6: Linear layer with 12544 input features and 1024 output features.
# Parameters: 12544×1024+102412544×1024+1024 (weights + bias)
#
# box_head.fc7: Linear layer with 1024 input features and 1024 output features.
# Parameters: 1024×1024+10241024×1024+1024 (weights + bias)
#
# Box Predictor Layers:
#
# box_predictor.cls_score: Linear layer with 1024 input features and 3 output features.
#
# Parameters: 1024×3+31024×3+3 (weights + bias)
#
# box_predictor.bbox_pred: Linear layer with 1024 input features and 12 output features.
#
# Parameters: 1024×12+121024×12+12 (weights + bias)
#
# Mask Head Layers:
# Each Conv2dNormActivation layer (4 in total) in mask_head has 256 input channels, 256 output channels, and a 3x3 kernel size.
#
# Parameters per layer: 256×256×3×3+256256×256×3×3+256 (weights + bias)
# Total for all layers: 256×256×3×3+256256×256×3×3+256 ×4×4
#
# Mask Predictor Layers:
# mask_predictor.conv5_mask: ConvTranspose2d layer with 256 input channels, 256 output channels, and a 2x2 kernel size.
#
# Parameters: 256×256×2×2+256256×256×2×2+256 (weights + bias)
#
# mask_predictor.mask_fcn_logits: Conv2d layer with 256 input channels, 3 output channels, and a 1x1 kernel size.
#
# Parameters: 256×3+3256×3+3 (weights + bias)
#
# Box Head Layers: 12544×1024+1024+1024×1024+102412544×1024+1024+1024×1024+1024
#
# Box Predictor Layers:
# 1024×3+3+1024×12+121024×3+3+1024×12+12
#
# Mask Head Layers:
# (256×256×3×3+256)×4(256×256×3×3+256)×4
#
# Mask Predictor Layers:
# 256×256×2×2+256+256×3+3256×256×2×2+256+256×3+3

# %% [markdown]
# Now we can finally start the training process.

# %%
num_epochs = 3

from engine import train_one_epoch, evaluate

for epoch in range(num_epochs):
    print("Epoch", epoch)
    # train for one epoch, printing every 10 iterations
    train_one_epoch(model_p2, optimizer, data_loader, device, epoch, print_freq=10)
    # update the learning rate
    lr_scheduler.step()
    # evaluate on the test dataset
    evaluate(model_p2, data_loader_test, device=device)
# Out:
# Epoch 0
# /opt/conda/envs/csciua-0480042-fall/lib/python3.8/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
#   return F.conv2d(input, weight, bias, self.stride,
# Epoch: [0]  [  0/300]  eta: 0:22:00  lr: 0.000022  loss: 4.6290 (4.6290)  loss_classifier: 1.1095 (1.1095)  loss_box_reg: 0.1524 (0.1524)  loss_mask: 3.3577 (3.3577)  loss_objectness: 0.0048 (0.0048)  loss_rpn_box_reg: 0.0045 (0.0045)  time: 4.4033  data: 0.0342  max mem: 941
# Epoch: [0]  [ 10/300]  eta: 0:03:09  lr: 0.000189  loss: 3.8663 (3.8200)  loss_classifier: 1.0128 (0.9890)  loss_box_reg: 0.1259 (0.1296)  loss_mask: 2.6848 (2.6832)  loss_objectness: 0.0026 (0.0043)  loss_rpn_box_reg: 0.0061 (0.0138)  time: 0.6549  data: 0.0292  max mem: 1235
# Epoch: [0]  [ 20/300]  eta: 0:02:13  lr: 0.000356  loss: 2.5428 (2.7406)  loss_classifier: 0.5645 (0.6764)  loss_box_reg: 0.1232 (0.1522)  loss_mask: 1.8858 (1.8938)  loss_objectness: 0.0028 (0.0058)  loss_rpn_box_reg: 0.0056 (0.0125)  time: 0.2805  data: 0.0303  max mem: 1341
# Epoch: [0]  [ 30/300]  eta: 0:01:52  lr: 0.000523  loss: 1.0874 (2.1977)  loss_classifier: 0.1727 (0.5129)  loss_box_reg: 0.1232 (0.1552)  loss_mask: 0.7082 (1.5098)  loss_objectness: 0.0031 (0.0052)  loss_rpn_box_reg: 0.0047 (0.0145)  time: 0.2860  data: 0.0322  max mem: 1414
# Epoch: [0]  [ 40/300]  eta: 0:01:39  lr: 0.000690  loss: 0.8223 (1.8585)  loss_classifier: 0.1445 (0.4245)  loss_box_reg: 0.1281 (0.1493)  loss_mask: 0.5039 (1.2638)  loss_objectness: 0.0031 (0.0053)  loss_rpn_box_reg: 0.0052 (0.0155)  time: 0.2848  data: 0.0293  max mem: 1414
# Epoch: [0]  [ 50/300]  eta: 0:01:30  lr: 0.000857  loss: 0.7455 (1.6769)  loss_classifier: 0.1477 (0.3705)  loss_box_reg: 0.1303 (0.1463)  loss_mask: 0.4155 (1.1393)  loss_objectness: 0.0041 (0.0052)  loss_rpn_box_reg: 0.0085 (0.0156)  time: 0.2743  data: 0.0265  max mem: 1414
# Epoch: [0]  [ 60/300]  eta: 0:01:22  lr: 0.001024  loss: 0.6057 (1.4966)  loss_classifier: 0.1253 (0.3284)  loss_box_reg: 0.1306 (0.1434)  loss_mask: 0.3508 (1.0052)  loss_objectness: 0.0026 (0.0050)  loss_rpn_box_reg: 0.0085 (0.0145)  time: 0.2678  data: 0.0265  max mem: 1414
# Epoch: [0]  [ 70/300]  eta: 0:01:17  lr: 0.001191  loss: 0.6057 (1.3858)  loss_classifier: 0.1081 (0.2986)  loss_box_reg: 0.1307 (0.1440)  loss_mask: 0.3424 (0.9241)  loss_objectness: 0.0023 (0.0047)  loss_rpn_box_reg: 0.0077 (0.0143)  time: 0.2683  data: 0.0288  max mem: 1414
# Epoch: [0]  [ 80/300]  eta: 0:01:11  lr: 0.001358  loss: 0.6489 (1.2918)  loss_classifier: 0.1042 (0.2747)  loss_box_reg: 0.1422 (0.1451)  loss_mask: 0.3152 (0.8532)  loss_objectness: 0.0027 (0.0050)  loss_rpn_box_reg: 0.0077 (0.0138)  time: 0.2702  data: 0.0303  max mem: 1414
# Epoch: [0]  [ 90/300]  eta: 0:01:07  lr: 0.001525  loss: 0.5764 (1.2219)  loss_classifier: 0.0951 (0.2562)  loss_box_reg: 0.1429 (0.1459)  loss_mask: 0.2858 (0.8006)  loss_objectness: 0.0071 (0.0054)  loss_rpn_box_reg: 0.0082 (0.0138)  time: 0.2756  data: 0.0302  max mem: 1414
# Epoch: [0]  [100/300]  eta: 0:01:03  lr: 0.001692  loss: 0.4448 (1.1546)  loss_classifier: 0.0826 (0.2392)  loss_box_reg: 0.1245 (0.1450)  loss_mask: 0.2374 (0.7507)  loss_objectness: 0.0056 (0.0055)  loss_rpn_box_reg: 0.0102 (0.0142)  time: 0.2818  data: 0.0312  max mem: 1414
# Epoch: [0]  [110/300]  eta: 0:00:59  lr: 0.001859  loss: 0.4512 (1.1027)  loss_classifier: 0.0786 (0.2252)  loss_box_reg: 0.1146 (0.1443)  loss_mask: 0.2451 (0.7138)  loss_objectness: 0.0047 (0.0055)  loss_rpn_box_reg: 0.0106 (0.0139)  time: 0.2878  data: 0.0328  max mem: 1414
# Epoch: [0]  [120/300]  eta: 0:00:56  lr: 0.002026  loss: 0.4972 (1.0515)  loss_classifier: 0.0676 (0.2119)  loss_box_reg: 0.1130 (0.1412)  loss_mask: 0.2699 (0.6784)  loss_objectness: 0.0035 (0.0057)  loss_rpn_box_reg: 0.0083 (0.0144)  time: 0.2852  data: 0.0303  max mem: 1414
# Epoch: [0]  [130/300]  eta: 0:00:52  lr: 0.002193  loss: 0.4215 (1.0046)  loss_classifier: 0.0558 (0.1999)  loss_box_reg: 0.1002 (0.1386)  loss_mask: 0.2551 (0.6465)  loss_objectness: 0.0026 (0.0055)  loss_rpn_box_reg: 0.0059 (0.0141)  time: 0.2809  data: 0.0263  max mem: 1478
# Epoch: [0]  [140/300]  eta: 0:00:49  lr: 0.002361  loss: 0.4415 (0.9721)  loss_classifier: 0.0540 (0.1898)  loss_box_reg: 0.1153 (0.1368)  loss_mask: 0.2560 (0.6263)  loss_objectness: 0.0024 (0.0055)  loss_rpn_box_reg: 0.0059 (0.0137)  time: 0.2699  data: 0.0256  max mem: 1478
# Epoch: [0]  [150/300]  eta: 0:00:45  lr: 0.002528  loss: 0.4189 (0.9339)  loss_classifier: 0.0493 (0.1804)  loss_box_reg: 0.1070 (0.1344)  loss_mask: 0.2734 (0.6003)  loss_objectness: 0.0024 (0.0053)  loss_rpn_box_reg: 0.0070 (0.0135)  time: 0.2635  data: 0.0256  max mem: 1478
# Epoch: [0]  [160/300]  eta: 0:00:42  lr: 0.002695  loss: 0.4246 (0.9069)  loss_classifier: 0.0493 (0.1739)  loss_box_reg: 0.0989 (0.1335)  loss_mask: 0.2629 (0.5809)  loss_objectness: 0.0027 (0.0054)  loss_rpn_box_reg: 0.0066 (0.0131)  time: 0.2842  data: 0.0267  max mem: 1609
# Epoch: [0]  [170/300]  eta: 0:00:39  lr: 0.002862  loss: 0.4592 (0.8872)  loss_classifier: 0.0661 (0.1674)  loss_box_reg: 0.1124 (0.1333)  loss_mask: 0.3020 (0.5678)  loss_objectness: 0.0038 (0.0054)  loss_rpn_box_reg: 0.0066 (0.0133)  time: 0.2867  data: 0.0285  max mem: 1609
# Epoch: [0]  [180/300]  eta: 0:00:36  lr: 0.003029  loss: 0.5340 (0.8834)  loss_classifier: 0.0439 (0.1606)  loss_box_reg: 0.1010 (0.1307)  loss_mask: 0.3186 (0.5730)  loss_objectness: 0.0037 (0.0054)  loss_rpn_box_reg: 0.0078 (0.0138)  time: 0.2716  data: 0.0272  max mem: 1609
# Epoch: [0]  [190/300]  eta: 0:00:32  lr: 0.003196  loss: 0.4698 (0.8657)  loss_classifier: 0.0412 (0.1548)  loss_box_reg: 0.0857 (0.1287)  loss_mask: 0.3162 (0.5632)  loss_objectness: 0.0039 (0.0054)  loss_rpn_box_reg: 0.0064 (0.0136)  time: 0.2745  data: 0.0256  max mem: 1609
# Epoch: [0]  [200/300]  eta: 0:00:29  lr: 0.003363  loss: 0.4698 (0.8508)  loss_classifier: 0.0484 (0.1500)  loss_box_reg: 0.0895 (0.1279)  loss_mask: 0.3049 (0.5543)  loss_objectness: 0.0046 (0.0054)  loss_rpn_box_reg: 0.0054 (0.0132)  time: 0.2799  data: 0.0282  max mem: 1609
# Epoch: [0]  [210/300]  eta: 0:00:26  lr: 0.003530  loss: 0.4834 (0.8345)  loss_classifier: 0.0404 (0.1450)  loss_box_reg: 0.0805 (0.1254)  loss_mask: 0.3028 (0.5455)  loss_objectness: 0.0039 (0.0054)  loss_rpn_box_reg: 0.0064 (0.0132)  time: 0.2670  data: 0.0272  max mem: 1609
# Epoch: [0]  [220/300]  eta: 0:00:23  lr: 0.003697  loss: 0.4875 (0.8232)  loss_classifier: 0.0386 (0.1405)  loss_box_reg: 0.0742 (0.1234)  loss_mask: 0.3596 (0.5408)  loss_objectness: 0.0035 (0.0053)  loss_rpn_box_reg: 0.0092 (0.0132)  time: 0.2703  data: 0.0275  max mem: 1609
# Epoch: [0]  [230/300]  eta: 0:00:20  lr: 0.003864  loss: 0.4875 (0.8107)  loss_classifier: 0.0386 (0.1364)  loss_box_reg: 0.0733 (0.1217)  loss_mask: 0.3596 (0.5340)  loss_objectness: 0.0033 (0.0053)  loss_rpn_box_reg: 0.0087 (0.0132)  time: 0.2797  data: 0.0313  max mem: 1609
# Epoch: [0]  [240/300]  eta: 0:00:17  lr: 0.004031  loss: 0.4264 (0.7998)  loss_classifier: 0.0420 (0.1328)  loss_box_reg: 0.0800 (0.1204)  loss_mask: 0.2746 (0.5280)  loss_objectness: 0.0015 (0.0053)  loss_rpn_box_reg: 0.0080 (0.0134)  time: 0.2747  data: 0.0297  max mem: 1609
# Epoch: [0]  [250/300]  eta: 0:00:14  lr: 0.004198  loss: 0.4431 (0.7851)  loss_classifier: 0.0458 (0.1292)  loss_box_reg: 0.0797 (0.1187)  loss_mask: 0.2770 (0.5187)  loss_objectness: 0.0022 (0.0053)  loss_rpn_box_reg: 0.0074 (0.0132)  time: 0.2811  data: 0.0273  max mem: 1609
# Epoch: [0]  [260/300]  eta: 0:00:11  lr: 0.004365  loss: 0.3834 (0.7703)  loss_classifier: 0.0384 (0.1259)  loss_box_reg: 0.0780 (0.1170)  loss_mask: 0.2654 (0.5092)  loss_objectness: 0.0035 (0.0052)  loss_rpn_box_reg: 0.0058 (0.0129)  time: 0.2745  data: 0.0260  max mem: 1609
# Epoch: [0]  [270/300]  eta: 0:00:08  lr: 0.004532  loss: 0.3802 (0.7594)  loss_classifier: 0.0334 (0.1235)  loss_box_reg: 0.0714 (0.1161)  loss_mask: 0.2820 (0.5017)  loss_objectness: 0.0052 (0.0052)  loss_rpn_box_reg: 0.0058 (0.0128)  time: 0.2715  data: 0.0257  max mem: 1609
# Epoch: [0]  [280/300]  eta: 0:00:05  lr: 0.004699  loss: 0.4171 (0.7478)  loss_classifier: 0.0355 (0.1208)  loss_box_reg: 0.0593 (0.1142)  loss_mask: 0.2964 (0.4936)  loss_objectness: 0.0066 (0.0054)  loss_rpn_box_reg: 0.0085 (0.0139)  time: 0.2789  data: 0.0258  max mem: 1609
# Epoch: [0]  [290/300]  eta: 0:00:02  lr: 0.004866  loss: 0.3930 (0.7368)  loss_classifier: 0.0383 (0.1181)  loss_box_reg: 0.0603 (0.1127)  loss_mask: 0.2356 (0.4867)  loss_objectness: 0.0046 (0.0054)  loss_rpn_box_reg: 0.0095 (0.0139)  time: 0.2747  data: 0.0254  max mem: 1609
# Epoch: [0]  [299/300]  eta: 0:00:00  lr: 0.005000  loss: 0.4172 (0.7299)  loss_classifier: 0.0381 (0.1159)  loss_box_reg: 0.0658 (0.1114)  loss_mask: 0.2964 (0.4834)  loss_objectness: 0.0038 (0.0054)  loss_rpn_box_reg: 0.0074 (0.0137)  time: 0.2762  data: 0.0257  max mem: 1609
# Epoch: [0] Total time: 0:01:27 (0.2906 s / it)
# creating index...
# index created!
# Test:  [  0/200]  eta: 0:00:39  model_time: 0.1776 (0.1776)  evaluator_time: 0.0090 (0.0090)  time: 0.1990  data: 0.0120  max mem: 1609
# Test:  [100/200]  eta: 0:00:14  model_time: 0.1285 (0.1273)  evaluator_time: 0.0061 (0.0058)  time: 0.1488  data: 0.0116  max mem: 1609
# Test:  [199/200]  eta: 0:00:00  model_time: 0.1295 (0.1270)  evaluator_time: 0.0046 (0.0054)  time: 0.1459  data: 0.0132  max mem: 1609
# Test: Total time: 0:00:29 (0.1450 s / it)
# Averaged stats: model_time: 0.1295 (0.1270)  evaluator_time: 0.0046 (0.0054)
# Accumulating evaluation results...
# DONE (t=0.07s).
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.447
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.849
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.414
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.465
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.457
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.509
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.623
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.624
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.639
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.622
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.459
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.833
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.490
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.342
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.515
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.516
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.614
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.614
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.622
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.615
# Epoch 1
# Epoch: [1]  [  0/300]  eta: 0:01:18  lr: 0.005000  loss: 0.4962 (0.4962)  loss_classifier: 0.0569 (0.0569)  loss_box_reg: 0.0856 (0.0856)  loss_mask: 0.3389 (0.3389)  loss_objectness: 0.0003 (0.0003)  loss_rpn_box_reg: 0.0144 (0.0144)  time: 0.2627  data: 0.0281  max mem: 1609
# Epoch: [1]  [ 10/300]  eta: 0:01:19  lr: 0.005000  loss: 0.5612 (0.5886)  loss_classifier: 0.0530 (0.0627)  loss_box_reg: 0.0767 (0.0936)  loss_mask: 0.4159 (0.4159)  loss_objectness: 0.0038 (0.0065)  loss_rpn_box_reg: 0.0061 (0.0099)  time: 0.2740  data: 0.0252  max mem: 1609
# Epoch: [1]  [ 20/300]  eta: 0:01:19  lr: 0.005000  loss: 0.4359 (0.4745)  loss_classifier: 0.0359 (0.0493)  loss_box_reg: 0.0613 (0.0766)  loss_mask: 0.2501 (0.3330)  loss_objectness: 0.0024 (0.0048)  loss_rpn_box_reg: 0.0065 (0.0108)  time: 0.2861  data: 0.0259  max mem: 1609
# Epoch: [1]  [ 30/300]  eta: 0:01:17  lr: 0.005000  loss: 0.3545 (0.4946)  loss_classifier: 0.0329 (0.0453)  loss_box_reg: 0.0610 (0.0736)  loss_mask: 0.2501 (0.3580)  loss_objectness: 0.0025 (0.0046)  loss_rpn_box_reg: 0.0087 (0.0131)  time: 0.2929  data: 0.0263  max mem: 1609
# Epoch: [1]  [ 40/300]  eta: 0:01:16  lr: 0.005000  loss: 0.3397 (0.4654)  loss_classifier: 0.0338 (0.0437)  loss_box_reg: 0.0517 (0.0690)  loss_mask: 0.2298 (0.3343)  loss_objectness: 0.0036 (0.0046)  loss_rpn_box_reg: 0.0080 (0.0138)  time: 0.3034  data: 0.0242  max mem: 1609
# Epoch: [1]  [ 50/300]  eta: 0:01:12  lr: 0.005000  loss: 0.3555 (0.4599)  loss_classifier: 0.0333 (0.0441)  loss_box_reg: 0.0571 (0.0699)  loss_mask: 0.2221 (0.3278)  loss_objectness: 0.0040 (0.0047)  loss_rpn_box_reg: 0.0070 (0.0133)  time: 0.2997  data: 0.0229  max mem: 1609
# Epoch: [1]  [ 60/300]  eta: 0:01:09  lr: 0.005000  loss: 0.4237 (0.4722)  loss_classifier: 0.0333 (0.0438)  loss_box_reg: 0.0602 (0.0691)  loss_mask: 0.3028 (0.3406)  loss_objectness: 0.0051 (0.0049)  loss_rpn_box_reg: 0.0071 (0.0138)  time: 0.2788  data: 0.0227  max mem: 1609
# Epoch: [1]  [ 70/300]  eta: 0:01:06  lr: 0.005000  loss: 0.4237 (0.4722)  loss_classifier: 0.0365 (0.0427)  loss_box_reg: 0.0625 (0.0690)  loss_mask: 0.3076 (0.3423)  loss_objectness: 0.0024 (0.0050)  loss_rpn_box_reg: 0.0054 (0.0132)  time: 0.2798  data: 0.0214  max mem: 1609
# Epoch: [1]  [ 80/300]  eta: 0:01:03  lr: 0.005000  loss: 0.4405 (0.4817)  loss_classifier: 0.0371 (0.0434)  loss_box_reg: 0.0724 (0.0692)  loss_mask: 0.3266 (0.3498)  loss_objectness: 0.0052 (0.0054)  loss_rpn_box_reg: 0.0065 (0.0138)  time: 0.2797  data: 0.0216  max mem: 1609
# Epoch: [1]  [ 90/300]  eta: 0:01:00  lr: 0.005000  loss: 0.4584 (0.4830)  loss_classifier: 0.0411 (0.0441)  loss_box_reg: 0.0737 (0.0699)  loss_mask: 0.3379 (0.3488)  loss_objectness: 0.0063 (0.0057)  loss_rpn_box_reg: 0.0116 (0.0145)  time: 0.2872  data: 0.0244  max mem: 1609
# Epoch: [1]  [100/300]  eta: 0:00:57  lr: 0.005000  loss: 0.4949 (0.4956)  loss_classifier: 0.0363 (0.0439)  loss_box_reg: 0.0618 (0.0697)  loss_mask: 0.3442 (0.3620)  loss_objectness: 0.0048 (0.0056)  loss_rpn_box_reg: 0.0099 (0.0144)  time: 0.2874  data: 0.0249  max mem: 1609
# Epoch: [1]  [110/300]  eta: 0:00:54  lr: 0.005000  loss: 0.4237 (0.4886)  loss_classifier: 0.0313 (0.0426)  loss_box_reg: 0.0593 (0.0690)  loss_mask: 0.3122 (0.3564)  loss_objectness: 0.0036 (0.0054)  loss_rpn_box_reg: 0.0084 (0.0152)  time: 0.2790  data: 0.0231  max mem: 1609
# Epoch: [1]  [120/300]  eta: 0:00:51  lr: 0.005000  loss: 0.4102 (0.4851)  loss_classifier: 0.0270 (0.0420)  loss_box_reg: 0.0576 (0.0686)  loss_mask: 0.2795 (0.3540)  loss_objectness: 0.0033 (0.0054)  loss_rpn_box_reg: 0.0084 (0.0151)  time: 0.2846  data: 0.0241  max mem: 1609
# Epoch: [1]  [130/300]  eta: 0:00:48  lr: 0.005000  loss: 0.4234 (0.4885)  loss_classifier: 0.0389 (0.0424)  loss_box_reg: 0.0674 (0.0694)  loss_mask: 0.3196 (0.3567)  loss_objectness: 0.0049 (0.0054)  loss_rpn_box_reg: 0.0068 (0.0144)  time: 0.2826  data: 0.0248  max mem: 1609
# Epoch: [1]  [140/300]  eta: 0:00:45  lr: 0.005000  loss: 0.4234 (0.4874)  loss_classifier: 0.0389 (0.0419)  loss_box_reg: 0.0715 (0.0698)  loss_mask: 0.3149 (0.3564)  loss_objectness: 0.0050 (0.0054)  loss_rpn_box_reg: 0.0051 (0.0138)  time: 0.2870  data: 0.0250  max mem: 1609
# Epoch: [1]  [150/300]  eta: 0:00:43  lr: 0.005000  loss: 0.3793 (0.4785)  loss_classifier: 0.0321 (0.0413)  loss_box_reg: 0.0600 (0.0690)  loss_mask: 0.2686 (0.3488)  loss_objectness: 0.0050 (0.0054)  loss_rpn_box_reg: 0.0046 (0.0140)  time: 0.2974  data: 0.0241  max mem: 1610
# Epoch: [1]  [160/300]  eta: 0:00:40  lr: 0.005000  loss: 0.4011 (0.4823)  loss_classifier: 0.0385 (0.0434)  loss_box_reg: 0.0665 (0.0709)  loss_mask: 0.2686 (0.3483)  loss_objectness: 0.0040 (0.0056)  loss_rpn_box_reg: 0.0074 (0.0141)  time: 0.2935  data: 0.0254  max mem: 1610
# Epoch: [1]  [170/300]  eta: 0:00:37  lr: 0.005000  loss: 0.4147 (0.4860)  loss_classifier: 0.0411 (0.0431)  loss_box_reg: 0.0792 (0.0709)  loss_mask: 0.2809 (0.3525)  loss_objectness: 0.0041 (0.0057)  loss_rpn_box_reg: 0.0079 (0.0138)  time: 0.2761  data: 0.0264  max mem: 1610
# Epoch: [1]  [180/300]  eta: 0:00:34  lr: 0.005000  loss: 0.4623 (0.4885)  loss_classifier: 0.0306 (0.0435)  loss_box_reg: 0.0707 (0.0712)  loss_mask: 0.3360 (0.3541)  loss_objectness: 0.0048 (0.0057)  loss_rpn_box_reg: 0.0076 (0.0140)  time: 0.2679  data: 0.0253  max mem: 1610
# Epoch: [1]  [190/300]  eta: 0:00:31  lr: 0.005000  loss: 0.4594 (0.4834)  loss_classifier: 0.0349 (0.0434)  loss_box_reg: 0.0618 (0.0718)  loss_mask: 0.2569 (0.3482)  loss_objectness: 0.0048 (0.0057)  loss_rpn_box_reg: 0.0089 (0.0142)  time: 0.2801  data: 0.0262  max mem: 1610
# Epoch: [1]  [200/300]  eta: 0:00:28  lr: 0.005000  loss: 0.3590 (0.4812)  loss_classifier: 0.0349 (0.0435)  loss_box_reg: 0.0607 (0.0717)  loss_mask: 0.2245 (0.3462)  loss_objectness: 0.0057 (0.0058)  loss_rpn_box_reg: 0.0099 (0.0141)  time: 0.2960  data: 0.0263  max mem: 1610
# Epoch: [1]  [210/300]  eta: 0:00:25  lr: 0.005000  loss: 0.3815 (0.4804)  loss_classifier: 0.0379 (0.0435)  loss_box_reg: 0.0592 (0.0713)  loss_mask: 0.2269 (0.3452)  loss_objectness: 0.0060 (0.0059)  loss_rpn_box_reg: 0.0111 (0.0145)  time: 0.2918  data: 0.0250  max mem: 1610
# Epoch: [1]  [220/300]  eta: 0:00:22  lr: 0.005000  loss: 0.3696 (0.4774)  loss_classifier: 0.0394 (0.0434)  loss_box_reg: 0.0637 (0.0717)  loss_mask: 0.2387 (0.3422)  loss_objectness: 0.0060 (0.0059)  loss_rpn_box_reg: 0.0074 (0.0142)  time: 0.2868  data: 0.0243  max mem: 1610
# Epoch: [1]  [230/300]  eta: 0:00:20  lr: 0.005000  loss: 0.3641 (0.4722)  loss_classifier: 0.0397 (0.0435)  loss_box_reg: 0.0694 (0.0720)  loss_mask: 0.2041 (0.3364)  loss_objectness: 0.0035 (0.0058)  loss_rpn_box_reg: 0.0055 (0.0144)  time: 0.2972  data: 0.0269  max mem: 1610
# Epoch: [1]  [240/300]  eta: 0:00:17  lr: 0.005000  loss: 0.3381 (0.4688)  loss_classifier: 0.0360 (0.0436)  loss_box_reg: 0.0694 (0.0723)  loss_mask: 0.1957 (0.3327)  loss_objectness: 0.0035 (0.0058)  loss_rpn_box_reg: 0.0062 (0.0143)  time: 0.2928  data: 0.0269  max mem: 1610
# Epoch: [1]  [250/300]  eta: 0:00:14  lr: 0.005000  loss: 0.3381 (0.4630)  loss_classifier: 0.0316 (0.0431)  loss_box_reg: 0.0699 (0.0719)  loss_mask: 0.1888 (0.3280)  loss_objectness: 0.0045 (0.0058)  loss_rpn_box_reg: 0.0061 (0.0141)  time: 0.2798  data: 0.0234  max mem: 1610
# Epoch: [1]  [260/300]  eta: 0:00:11  lr: 0.005000  loss: 0.3500 (0.4604)  loss_classifier: 0.0342 (0.0435)  loss_box_reg: 0.0658 (0.0721)  loss_mask: 0.2028 (0.3249)  loss_objectness: 0.0040 (0.0058)  loss_rpn_box_reg: 0.0068 (0.0142)  time: 0.2783  data: 0.0229  max mem: 1610
# Epoch: [1]  [270/300]  eta: 0:00:08  lr: 0.005000  loss: 0.3392 (0.4573)  loss_classifier: 0.0418 (0.0440)  loss_box_reg: 0.0661 (0.0724)  loss_mask: 0.2010 (0.3209)  loss_objectness: 0.0030 (0.0058)  loss_rpn_box_reg: 0.0077 (0.0141)  time: 0.2878  data: 0.0266  max mem: 1610
# Epoch: [1]  [280/300]  eta: 0:00:05  lr: 0.005000  loss: 0.3244 (0.4539)  loss_classifier: 0.0402 (0.0437)  loss_box_reg: 0.0661 (0.0721)  loss_mask: 0.1779 (0.3181)  loss_objectness: 0.0054 (0.0059)  loss_rpn_box_reg: 0.0106 (0.0141)  time: 0.2933  data: 0.0288  max mem: 1610
# Epoch: [1]  [290/300]  eta: 0:00:02  lr: 0.005000  loss: 0.3244 (0.4528)  loss_classifier: 0.0323 (0.0436)  loss_box_reg: 0.0614 (0.0722)  loss_mask: 0.2039 (0.3172)  loss_objectness: 0.0058 (0.0059)  loss_rpn_box_reg: 0.0091 (0.0139)  time: 0.2851  data: 0.0266  max mem: 1610
# Epoch: [1]  [299/300]  eta: 0:00:00  lr: 0.005000  loss: 0.3157 (0.4528)  loss_classifier: 0.0323 (0.0440)  loss_box_reg: 0.0639 (0.0735)  loss_mask: 0.2039 (0.3156)  loss_objectness: 0.0069 (0.0060)  loss_rpn_box_reg: 0.0069 (0.0138)  time: 0.2876  data: 0.0270  max mem: 1610
# Epoch: [1] Total time: 0:01:26 (0.2869 s / it)
# creating index...
# index created!
# Test:  [  0/200]  eta: 0:00:38  model_time: 0.1743 (0.1743)  evaluator_time: 0.0044 (0.0044)  time: 0.1903  data: 0.0113  max mem: 1610
# Test:  [100/200]  eta: 0:00:14  model_time: 0.1278 (0.1261)  evaluator_time: 0.0058 (0.0055)  time: 0.1460  data: 0.0117  max mem: 1610
# Test:  [199/200]  eta: 0:00:00  model_time: 0.1246 (0.1256)  evaluator_time: 0.0049 (0.0051)  time: 0.1442  data: 0.0141  max mem: 1610
# Test: Total time: 0:00:28 (0.1436 s / it)
# Averaged stats: model_time: 0.1246 (0.1256)  evaluator_time: 0.0049 (0.0051)
# Accumulating evaluation results...
# DONE (t=0.06s).
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.466
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.873
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.449
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.475
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.476
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.513
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.620
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.620
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.615
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.622
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.511
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.873
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.542
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.352
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.571
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.556
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.662
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.663
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.676
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.661
# Epoch 2
# Epoch: [2]  [  0/300]  eta: 0:01:29  lr: 0.005000  loss: 0.3137 (0.3137)  loss_classifier: 0.0356 (0.0356)  loss_box_reg: 0.0448 (0.0448)  loss_mask: 0.2191 (0.2191)  loss_objectness: 0.0003 (0.0003)  loss_rpn_box_reg: 0.0138 (0.0138)  time: 0.2968  data: 0.0267  max mem: 1610
# Epoch: [2]  [ 10/300]  eta: 0:01:29  lr: 0.005000  loss: 0.3137 (0.3635)  loss_classifier: 0.0400 (0.0464)  loss_box_reg: 0.0564 (0.0740)  loss_mask: 0.2124 (0.2249)  loss_objectness: 0.0045 (0.0060)  loss_rpn_box_reg: 0.0085 (0.0122)  time: 0.3082  data: 0.0266  max mem: 1610
# Epoch: [2]  [ 20/300]  eta: 0:01:23  lr: 0.005000  loss: 0.3095 (0.3821)  loss_classifier: 0.0400 (0.0455)  loss_box_reg: 0.0597 (0.0760)  loss_mask: 0.2041 (0.2436)  loss_objectness: 0.0027 (0.0052)  loss_rpn_box_reg: 0.0085 (0.0119)  time: 0.2987  data: 0.0260  max mem: 1610
# Epoch: [2]  [ 30/300]  eta: 0:01:21  lr: 0.005000  loss: 0.3777 (0.3896)  loss_classifier: 0.0371 (0.0445)  loss_box_reg: 0.0640 (0.0758)  loss_mask: 0.2599 (0.2535)  loss_objectness: 0.0037 (0.0053)  loss_rpn_box_reg: 0.0063 (0.0106)  time: 0.2994  data: 0.0259  max mem: 1610
# Epoch: [2]  [ 40/300]  eta: 0:01:17  lr: 0.005000  loss: 0.3959 (0.4125)  loss_classifier: 0.0344 (0.0437)  loss_box_reg: 0.0620 (0.0744)  loss_mask: 0.2704 (0.2778)  loss_objectness: 0.0040 (0.0051)  loss_rpn_box_reg: 0.0063 (0.0114)  time: 0.2942  data: 0.0246  max mem: 1610
# Epoch: [2]  [ 50/300]  eta: 0:01:14  lr: 0.005000  loss: 0.4363 (0.4081)  loss_classifier: 0.0320 (0.0422)  loss_box_reg: 0.0593 (0.0717)  loss_mask: 0.2714 (0.2776)  loss_objectness: 0.0021 (0.0053)  loss_rpn_box_reg: 0.0054 (0.0112)  time: 0.2877  data: 0.0233  max mem: 1610
# Epoch: [2]  [ 60/300]  eta: 0:01:10  lr: 0.005000  loss: 0.3398 (0.4101)  loss_classifier: 0.0306 (0.0427)  loss_box_reg: 0.0549 (0.0709)  loss_mask: 0.2381 (0.2794)  loss_objectness: 0.0044 (0.0056)  loss_rpn_box_reg: 0.0045 (0.0116)  time: 0.2945  data: 0.0245  max mem: 1610
# Epoch: [2]  [ 70/300]  eta: 0:01:07  lr: 0.005000  loss: 0.3565 (0.4101)  loss_classifier: 0.0368 (0.0430)  loss_box_reg: 0.0547 (0.0726)  loss_mask: 0.2166 (0.2770)  loss_objectness: 0.0059 (0.0055)  loss_rpn_box_reg: 0.0092 (0.0121)  time: 0.2904  data: 0.0259  max mem: 1610
# Epoch: [2]  [ 80/300]  eta: 0:01:04  lr: 0.005000  loss: 0.3565 (0.4050)  loss_classifier: 0.0354 (0.0424)  loss_box_reg: 0.0655 (0.0741)  loss_mask: 0.2135 (0.2700)  loss_objectness: 0.0031 (0.0053)  loss_rpn_box_reg: 0.0089 (0.0132)  time: 0.2886  data: 0.0270  max mem: 1610
# Epoch: [2]  [ 90/300]  eta: 0:01:01  lr: 0.005000  loss: 0.3278 (0.4026)  loss_classifier: 0.0291 (0.0415)  loss_box_reg: 0.0640 (0.0725)  loss_mask: 0.2158 (0.2701)  loss_objectness: 0.0029 (0.0052)  loss_rpn_box_reg: 0.0089 (0.0132)  time: 0.2815  data: 0.0263  max mem: 1610
# Epoch: [2]  [100/300]  eta: 0:00:58  lr: 0.005000  loss: 0.3262 (0.3941)  loss_classifier: 0.0284 (0.0416)  loss_box_reg: 0.0588 (0.0718)  loss_mask: 0.2215 (0.2628)  loss_objectness: 0.0029 (0.0053)  loss_rpn_box_reg: 0.0061 (0.0126)  time: 0.2778  data: 0.0234  max mem: 1610
# Epoch: [2]  [110/300]  eta: 0:00:55  lr: 0.005000  loss: 0.3029 (0.3875)  loss_classifier: 0.0361 (0.0411)  loss_box_reg: 0.0562 (0.0714)  loss_mask: 0.1989 (0.2568)  loss_objectness: 0.0046 (0.0053)  loss_rpn_box_reg: 0.0061 (0.0129)  time: 0.2787  data: 0.0225  max mem: 1610
# Epoch: [2]  [120/300]  eta: 0:00:51  lr: 0.005000  loss: 0.3332 (0.3861)  loss_classifier: 0.0390 (0.0412)  loss_box_reg: 0.0638 (0.0715)  loss_mask: 0.1935 (0.2551)  loss_objectness: 0.0046 (0.0053)  loss_rpn_box_reg: 0.0060 (0.0130)  time: 0.2791  data: 0.0236  max mem: 1610
# Epoch: [2]  [130/300]  eta: 0:00:49  lr: 0.005000  loss: 0.3374 (0.3849)  loss_classifier: 0.0376 (0.0405)  loss_box_reg: 0.0699 (0.0711)  loss_mask: 0.2023 (0.2548)  loss_objectness: 0.0038 (0.0054)  loss_rpn_box_reg: 0.0060 (0.0132)  time: 0.2877  data: 0.0266  max mem: 1610
# Epoch: [2]  [140/300]  eta: 0:00:46  lr: 0.005000  loss: 0.3374 (0.3822)  loss_classifier: 0.0320 (0.0408)  loss_box_reg: 0.0667 (0.0707)  loss_mask: 0.2052 (0.2522)  loss_objectness: 0.0041 (0.0054)  loss_rpn_box_reg: 0.0075 (0.0132)  time: 0.2807  data: 0.0274  max mem: 1610
# Epoch: [2]  [150/300]  eta: 0:00:43  lr: 0.005000  loss: 0.3270 (0.3828)  loss_classifier: 0.0312 (0.0405)  loss_box_reg: 0.0588 (0.0693)  loss_mask: 0.2146 (0.2544)  loss_objectness: 0.0031 (0.0054)  loss_rpn_box_reg: 0.0087 (0.0133)  time: 0.2746  data: 0.0247  max mem: 1610
# Epoch: [2]  [160/300]  eta: 0:00:40  lr: 0.005000  loss: 0.3200 (0.3822)  loss_classifier: 0.0292 (0.0412)  loss_box_reg: 0.0598 (0.0705)  loss_mask: 0.2131 (0.2523)  loss_objectness: 0.0025 (0.0053)  loss_rpn_box_reg: 0.0083 (0.0129)  time: 0.2879  data: 0.0254  max mem: 1610
# Epoch: [2]  [170/300]  eta: 0:00:37  lr: 0.005000  loss: 0.2978 (0.3806)  loss_classifier: 0.0297 (0.0408)  loss_box_reg: 0.0640 (0.0701)  loss_mask: 0.1864 (0.2515)  loss_objectness: 0.0060 (0.0055)  loss_rpn_box_reg: 0.0053 (0.0128)  time: 0.2847  data: 0.0240  max mem: 1610
# Epoch: [2]  [180/300]  eta: 0:00:34  lr: 0.005000  loss: 0.3389 (0.3841)  loss_classifier: 0.0337 (0.0410)  loss_box_reg: 0.0592 (0.0705)  loss_mask: 0.1924 (0.2542)  loss_objectness: 0.0061 (0.0055)  loss_rpn_box_reg: 0.0087 (0.0129)  time: 0.2825  data: 0.0219  max mem: 1610
# Epoch: [2]  [190/300]  eta: 0:00:31  lr: 0.005000  loss: 0.3519 (0.3839)  loss_classifier: 0.0343 (0.0417)  loss_box_reg: 0.0575 (0.0711)  loss_mask: 0.2230 (0.2525)  loss_objectness: 0.0041 (0.0054)  loss_rpn_box_reg: 0.0086 (0.0131)  time: 0.2938  data: 0.0251  max mem: 1610
# Epoch: [2]  [200/300]  eta: 0:00:28  lr: 0.005000  loss: 0.3566 (0.3865)  loss_classifier: 0.0290 (0.0412)  loss_box_reg: 0.0575 (0.0705)  loss_mask: 0.2355 (0.2554)  loss_objectness: 0.0045 (0.0055)  loss_rpn_box_reg: 0.0156 (0.0139)  time: 0.2947  data: 0.0263  max mem: 1610
# Epoch: [2]  [210/300]  eta: 0:00:25  lr: 0.005000  loss: 0.3304 (0.3834)  loss_classifier: 0.0311 (0.0409)  loss_box_reg: 0.0549 (0.0698)  loss_mask: 0.2355 (0.2534)  loss_objectness: 0.0054 (0.0055)  loss_rpn_box_reg: 0.0142 (0.0139)  time: 0.2899  data: 0.0237  max mem: 1610
# Epoch: [2]  [220/300]  eta: 0:00:23  lr: 0.005000  loss: 0.2954 (0.3827)  loss_classifier: 0.0312 (0.0412)  loss_box_reg: 0.0467 (0.0695)  loss_mask: 0.2101 (0.2524)  loss_objectness: 0.0027 (0.0056)  loss_rpn_box_reg: 0.0082 (0.0139)  time: 0.2933  data: 0.0254  max mem: 1610
# Epoch: [2]  [230/300]  eta: 0:00:20  lr: 0.005000  loss: 0.3019 (0.3805)  loss_classifier: 0.0273 (0.0410)  loss_box_reg: 0.0552 (0.0695)  loss_mask: 0.2080 (0.2504)  loss_objectness: 0.0026 (0.0056)  loss_rpn_box_reg: 0.0106 (0.0141)  time: 0.2941  data: 0.0268  max mem: 1610
# Epoch: [2]  [240/300]  eta: 0:00:17  lr: 0.005000  loss: 0.3019 (0.3779)  loss_classifier: 0.0273 (0.0412)  loss_box_reg: 0.0584 (0.0699)  loss_mask: 0.1790 (0.2473)  loss_objectness: 0.0027 (0.0055)  loss_rpn_box_reg: 0.0106 (0.0140)  time: 0.3020  data: 0.0251  max mem: 1611
# Epoch: [2]  [250/300]  eta: 0:00:14  lr: 0.005000  loss: 0.3190 (0.3770)  loss_classifier: 0.0374 (0.0415)  loss_box_reg: 0.0632 (0.0701)  loss_mask: 0.1951 (0.2463)  loss_objectness: 0.0031 (0.0054)  loss_rpn_box_reg: 0.0054 (0.0137)  time: 0.2962  data: 0.0253  max mem: 1611
# Epoch: [2]  [260/300]  eta: 0:00:11  lr: 0.005000  loss: 0.3679 (0.3768)  loss_classifier: 0.0374 (0.0414)  loss_box_reg: 0.0698 (0.0703)  loss_mask: 0.2229 (0.2463)  loss_objectness: 0.0038 (0.0054)  loss_rpn_box_reg: 0.0051 (0.0134)  time: 0.2848  data: 0.0243  max mem: 1611
# Epoch: [2]  [270/300]  eta: 0:00:08  lr: 0.005000  loss: 0.3679 (0.3766)  loss_classifier: 0.0363 (0.0415)  loss_box_reg: 0.0588 (0.0707)  loss_mask: 0.2229 (0.2454)  loss_objectness: 0.0038 (0.0054)  loss_rpn_box_reg: 0.0053 (0.0136)  time: 0.3016  data: 0.0267  max mem: 1611
# Epoch: [2]  [280/300]  eta: 0:00:05  lr: 0.005000  loss: 0.3588 (0.3774)  loss_classifier: 0.0331 (0.0418)  loss_box_reg: 0.0764 (0.0716)  loss_mask: 0.2132 (0.2451)  loss_objectness: 0.0047 (0.0054)  loss_rpn_box_reg: 0.0053 (0.0135)  time: 0.3101  data: 0.0305  max mem: 1611
# Epoch: [2]  [290/300]  eta: 0:00:02  lr: 0.005000  loss: 0.3588 (0.3831)  loss_classifier: 0.0345 (0.0416)  loss_box_reg: 0.0704 (0.0713)  loss_mask: 0.2329 (0.2511)  loss_objectness: 0.0070 (0.0055)  loss_rpn_box_reg: 0.0071 (0.0136)  time: 0.2934  data: 0.0269  max mem: 1611
# Epoch: [2]  [299/300]  eta: 0:00:00  lr: 0.005000  loss: 0.3936 (0.3833)  loss_classifier: 0.0370 (0.0417)  loss_box_reg: 0.0673 (0.0713)  loss_mask: 0.2445 (0.2511)  loss_objectness: 0.0087 (0.0056)  loss_rpn_box_reg: 0.0092 (0.0137)  time: 0.2782  data: 0.0259  max mem: 1611
# Epoch: [2] Total time: 0:01:27 (0.2901 s / it)
# creating index...
# index created!
# Test:  [  0/200]  eta: 0:00:36  model_time: 0.1650 (0.1650)  evaluator_time: 0.0036 (0.0036)  time: 0.1848  data: 0.0158  max mem: 1611
# Test:  [100/200]  eta: 0:00:13  model_time: 0.1265 (0.1229)  evaluator_time: 0.0044 (0.0043)  time: 0.1431  data: 0.0119  max mem: 1611
# Test:  [199/200]  eta: 0:00:00  model_time: 0.1231 (0.1231)  evaluator_time: 0.0038 (0.0040)  time: 0.1407  data: 0.0135  max mem: 1611
# Test: Total time: 0:00:27 (0.1399 s / it)
# Averaged stats: model_time: 0.1231 (0.1231)  evaluator_time: 0.0038 (0.0040)
# Accumulating evaluation results...
# DONE (t=0.05s).
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.504
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.899
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.563
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.456
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.520
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.534
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.631
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.631
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.575
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.643
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.494
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.866
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.501
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.383
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.531
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.534
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.626
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.626
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.609
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.631

# %% [markdown]
# In order to analyze the output, you'll need to know what an IoU score is. You can read this blog: https://www.pyimagesearch.com/2016/11/07/intersection-over-union-iou-for-object-detection/

# %% [markdown]
# ## Question 8 [10%]
#
# In an image (grey box) of size 12x16, there is an object whose ground truth mask is the box with the dashed edge (green color) and the model's predicted mask is the box with the dash-dotted edge (red color). Calculate the IoU score for this prediction.
#
# ![Image](../shared/HW3/img/plot.png)

# %% [markdown]
# #### Answer :
# 0.5

# %% [markdown]
# Let's see the model's prediction for a sample from the test set.

# %%
img, target = dataset_test[1]

# put the model in evaluation mode
model_p2.eval()

with torch.no_grad():
    prediction = model_p2([img.to(device)])

# %% [markdown]
# Here's the sample image.

# %%
Image.fromarray(img.mul(255).permute(1, 2, 0).byte().numpy())
# Out:
# <PIL.Image.Image image mode=RGB size=259x194>

# %% [markdown]
# And here's the mask generated by the finetuned model.

# %%
Image.fromarray(prediction[0]['masks'][0, 0].mul(255).byte().cpu().numpy())
# Out:
# <PIL.Image.Image image mode=L size=259x194>

# %% [markdown]
# # 3. Finetuning the Entire Network

# %% [markdown]
# Let's see what happens when we fine-tune the entire network. That is, instead of just learning the weights in the final layers, we'll let the weights of the entire network change during the training process.

# %%
model_p3 = torchvision.models.detection.maskrcnn_resnet50_fpn(pretrained=True)

# %% [markdown]
# ## Question 9 [5%]
#
# Just like in question 5, we're interested in fine-tuning the pretrained model for our new dataset, so we will again need to modify its box predictor (FastRCNNPredictor) and its mask predictor (MaskRCNNPredictor) to match with our new dataset. Complete the code cell below. Hint: This is exactly the same as question 5.

# %%
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.models.detection.mask_rcnn import MaskRCNNPredictor

# Our new dataset has 3 classes: butterfly, squirrel and background
num_classes = 3

# Get number of input features for the classifier
in_features = model_p3.roi_heads.box_predictor.cls_score.in_features

# TODO: replace the pre-trained head with a new one
model_p3.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

# Get number of input features for the mask predictor
in_features_mask = model_p3.roi_heads.mask_predictor.conv5_mask.in_channels
hidden_layer = 256

# TODO: replace the mask predictor with a new one
model_p3.roi_heads.mask_predictor = MaskRCNNPredictor(in_features_mask, hidden_layer, num_classes)

# %% [markdown]
# Again, let's ensure that we're using the GPU by printing the device info. This finetuning process takes even longer because we have more trainable parameters, hence there will be more computations.

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
print("Using : ", device)

model_p3 = model_p3.to(device)
# Out:
# Using :  cuda

# %% [markdown]
# We'll use the same optimizer and learning rate scheduler as before.

# %%
params = [p for p in model_p3.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, lr=0.005, momentum=0.9, weight_decay=0.0005)
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                                step_size=3,
                                                gamma=0.1)

# %% [markdown]
# Let's start the finetuning process.

# %%
num_epochs = 3

from engine import train_one_epoch, evaluate

for epoch in range(num_epochs):
    print("Epoch", epoch)
    # train for one epoch, printing every 10 iterations
    train_one_epoch(model_p3, optimizer, data_loader, device, epoch, print_freq=10)
    # update the learning rate
    lr_scheduler.step()
    # evaluate on the test dataset
    evaluate(model_p3, data_loader_test, device=device)
# Out:
# Epoch 0
# Epoch: [0]  [  0/300]  eta: 0:03:21  lr: 0.000022  loss: 3.5543 (3.5543)  loss_classifier: 1.0075 (1.0075)  loss_box_reg: 0.2697 (0.2697)  loss_mask: 2.2649 (2.2649)  loss_objectness: 0.0048 (0.0048)  loss_rpn_box_reg: 0.0075 (0.0075)  time: 0.6702  data: 0.0351  max mem: 4502
# Epoch: [0]  [ 10/300]  eta: 0:02:51  lr: 0.000189  loss: 2.7750 (2.5224)  loss_classifier: 0.7955 (0.7417)  loss_box_reg: 0.1382 (0.1605)  loss_mask: 1.6473 (1.6085)  loss_objectness: 0.0028 (0.0028)  loss_rpn_box_reg: 0.0072 (0.0089)  time: 0.5921  data: 0.0267  max mem: 4502
# Epoch: [0]  [ 20/300]  eta: 0:02:50  lr: 0.000356  loss: 1.3512 (1.7301)  loss_classifier: 0.3054 (0.4564)  loss_box_reg: 0.1306 (0.1450)  loss_mask: 0.8832 (1.1129)  loss_objectness: 0.0028 (0.0032)  loss_rpn_box_reg: 0.0090 (0.0127)  time: 0.6059  data: 0.0246  max mem: 4502
# Epoch: [0]  [ 30/300]  eta: 0:02:47  lr: 0.000523  loss: 0.5507 (1.3262)  loss_classifier: 0.0870 (0.3333)  loss_box_reg: 0.1309 (0.1373)  loss_mask: 0.2908 (0.8392)  loss_objectness: 0.0031 (0.0033)  loss_rpn_box_reg: 0.0121 (0.0130)  time: 0.6357  data: 0.0241  max mem: 5267
# Epoch: [0]  [ 40/300]  eta: 0:02:39  lr: 0.000690  loss: 0.4374 (1.1091)  loss_classifier: 0.0782 (0.2744)  loss_box_reg: 0.1214 (0.1359)  loss_mask: 0.2154 (0.6834)  loss_objectness: 0.0024 (0.0031)  loss_rpn_box_reg: 0.0067 (0.0122)  time: 0.6213  data: 0.0247  max mem: 5267
# Epoch: [0]  [ 50/300]  eta: 0:02:34  lr: 0.000857  loss: 0.3979 (0.9694)  loss_classifier: 0.0752 (0.2352)  loss_box_reg: 0.1188 (0.1343)  loss_mask: 0.1687 (0.5837)  loss_objectness: 0.0017 (0.0030)  loss_rpn_box_reg: 0.0061 (0.0132)  time: 0.6149  data: 0.0246  max mem: 5267
# Epoch: [0]  [ 60/300]  eta: 0:02:29  lr: 0.001024  loss: 0.4006 (0.8802)  loss_classifier: 0.0630 (0.2083)  loss_box_reg: 0.1137 (0.1314)  loss_mask: 0.1687 (0.5248)  loss_objectness: 0.0025 (0.0033)  loss_rpn_box_reg: 0.0061 (0.0124)  time: 0.6336  data: 0.0247  max mem: 5634
# Epoch: [0]  [ 70/300]  eta: 0:02:22  lr: 0.001191  loss: 0.3689 (0.8084)  loss_classifier: 0.0581 (0.1867)  loss_box_reg: 0.1091 (0.1290)  loss_mask: 0.1888 (0.4753)  loss_objectness: 0.0025 (0.0045)  loss_rpn_box_reg: 0.0055 (0.0128)  time: 0.6245  data: 0.0235  max mem: 5634
# Epoch: [0]  [ 80/300]  eta: 0:02:16  lr: 0.001358  loss: 0.3682 (0.7544)  loss_classifier: 0.0500 (0.1705)  loss_box_reg: 0.1116 (0.1277)  loss_mask: 0.1888 (0.4390)  loss_objectness: 0.0023 (0.0046)  loss_rpn_box_reg: 0.0084 (0.0125)  time: 0.6159  data: 0.0230  max mem: 5634
# Epoch: [0]  [ 90/300]  eta: 0:02:09  lr: 0.001525  loss: 0.3509 (0.7085)  loss_classifier: 0.0464 (0.1567)  loss_box_reg: 0.1097 (0.1248)  loss_mask: 0.1682 (0.4099)  loss_objectness: 0.0023 (0.0046)  loss_rpn_box_reg: 0.0098 (0.0125)  time: 0.6132  data: 0.0246  max mem: 5634
# Epoch: [0]  [100/300]  eta: 0:02:03  lr: 0.001692  loss: 0.3131 (0.6710)  loss_classifier: 0.0432 (0.1468)  loss_box_reg: 0.0995 (0.1228)  loss_mask: 0.1488 (0.3836)  loss_objectness: 0.0027 (0.0045)  loss_rpn_box_reg: 0.0095 (0.0132)  time: 0.6091  data: 0.0248  max mem: 5634
# Epoch: [0]  [110/300]  eta: 0:01:57  lr: 0.001859  loss: 0.3160 (0.6460)  loss_classifier: 0.0455 (0.1393)  loss_box_reg: 0.1133 (0.1238)  loss_mask: 0.1349 (0.3659)  loss_objectness: 0.0027 (0.0043)  loss_rpn_box_reg: 0.0063 (0.0127)  time: 0.6091  data: 0.0264  max mem: 5634
# Epoch: [0]  [120/300]  eta: 0:01:50  lr: 0.002026  loss: 0.3295 (0.6257)  loss_classifier: 0.0468 (0.1326)  loss_box_reg: 0.1133 (0.1238)  loss_mask: 0.1482 (0.3521)  loss_objectness: 0.0011 (0.0044)  loss_rpn_box_reg: 0.0071 (0.0129)  time: 0.6102  data: 0.0286  max mem: 5634
# Epoch: [0]  [130/300]  eta: 0:01:44  lr: 0.002193  loss: 0.3067 (0.6082)  loss_classifier: 0.0408 (0.1261)  loss_box_reg: 0.0925 (0.1226)  loss_mask: 0.1456 (0.3420)  loss_objectness: 0.0018 (0.0042)  loss_rpn_box_reg: 0.0094 (0.0132)  time: 0.6203  data: 0.0276  max mem: 5634
# Epoch: [0]  [140/300]  eta: 0:01:38  lr: 0.002361  loss: 0.2814 (0.5868)  loss_classifier: 0.0354 (0.1200)  loss_box_reg: 0.0850 (0.1203)  loss_mask: 0.1451 (0.3293)  loss_objectness: 0.0020 (0.0042)  loss_rpn_box_reg: 0.0063 (0.0131)  time: 0.6181  data: 0.0263  max mem: 5634
# Epoch: [0]  [150/300]  eta: 0:01:32  lr: 0.002528  loss: 0.2801 (0.5665)  loss_classifier: 0.0325 (0.1141)  loss_box_reg: 0.0784 (0.1172)  loss_mask: 0.1363 (0.3182)  loss_objectness: 0.0020 (0.0042)  loss_rpn_box_reg: 0.0057 (0.0128)  time: 0.6024  data: 0.0256  max mem: 5634
# Epoch: [0]  [160/300]  eta: 0:01:26  lr: 0.002695  loss: 0.3022 (0.5552)  loss_classifier: 0.0324 (0.1097)  loss_box_reg: 0.0769 (0.1157)  loss_mask: 0.1636 (0.3130)  loss_objectness: 0.0010 (0.0040)  loss_rpn_box_reg: 0.0069 (0.0128)  time: 0.6140  data: 0.0258  max mem: 5634
# Epoch: [0]  [170/300]  eta: 0:01:20  lr: 0.002862  loss: 0.3080 (0.5406)  loss_classifier: 0.0355 (0.1058)  loss_box_reg: 0.0800 (0.1143)  loss_mask: 0.1685 (0.3038)  loss_objectness: 0.0010 (0.0038)  loss_rpn_box_reg: 0.0117 (0.0129)  time: 0.6557  data: 0.0262  max mem: 5634
# Epoch: [0]  [180/300]  eta: 0:01:14  lr: 0.003029  loss: 0.2997 (0.5315)  loss_classifier: 0.0346 (0.1021)  loss_box_reg: 0.0742 (0.1125)  loss_mask: 0.1430 (0.3006)  loss_objectness: 0.0011 (0.0038)  loss_rpn_box_reg: 0.0066 (0.0125)  time: 0.6465  data: 0.0273  max mem: 5634
# Epoch: [0]  [190/300]  eta: 0:01:08  lr: 0.003196  loss: 0.2733 (0.5191)  loss_classifier: 0.0345 (0.0984)  loss_box_reg: 0.0606 (0.1098)  loss_mask: 0.1486 (0.2946)  loss_objectness: 0.0013 (0.0038)  loss_rpn_box_reg: 0.0051 (0.0125)  time: 0.6132  data: 0.0277  max mem: 5634
# Epoch: [0]  [200/300]  eta: 0:01:02  lr: 0.003363  loss: 0.2646 (0.5077)  loss_classifier: 0.0246 (0.0954)  loss_box_reg: 0.0514 (0.1073)  loss_mask: 0.1492 (0.2886)  loss_objectness: 0.0017 (0.0038)  loss_rpn_box_reg: 0.0062 (0.0126)  time: 0.6313  data: 0.0261  max mem: 5635
# Epoch: [0]  [210/300]  eta: 0:00:55  lr: 0.003530  loss: 0.2646 (0.4976)  loss_classifier: 0.0290 (0.0925)  loss_box_reg: 0.0642 (0.1056)  loss_mask: 0.1492 (0.2835)  loss_objectness: 0.0013 (0.0037)  loss_rpn_box_reg: 0.0050 (0.0123)  time: 0.6238  data: 0.0260  max mem: 5635
# Epoch: [0]  [220/300]  eta: 0:00:49  lr: 0.003697  loss: 0.3441 (0.5000)  loss_classifier: 0.0304 (0.0904)  loss_box_reg: 0.0645 (0.1054)  loss_mask: 0.2058 (0.2881)  loss_objectness: 0.0011 (0.0036)  loss_rpn_box_reg: 0.0051 (0.0125)  time: 0.6280  data: 0.0319  max mem: 5635
# Epoch: [0]  [230/300]  eta: 0:00:43  lr: 0.003864  loss: 0.4390 (0.4942)  loss_classifier: 0.0268 (0.0883)  loss_box_reg: 0.0713 (0.1045)  loss_mask: 0.2488 (0.2856)  loss_objectness: 0.0013 (0.0036)  loss_rpn_box_reg: 0.0076 (0.0123)  time: 0.6330  data: 0.0326  max mem: 5635
# Epoch: [0]  [240/300]  eta: 0:00:37  lr: 0.004031  loss: 0.3510 (0.4892)  loss_classifier: 0.0343 (0.0866)  loss_box_reg: 0.0759 (0.1035)  loss_mask: 0.2264 (0.2834)  loss_objectness: 0.0017 (0.0037)  loss_rpn_box_reg: 0.0069 (0.0121)  time: 0.6117  data: 0.0262  max mem: 5635
# Epoch: [0]  [250/300]  eta: 0:00:31  lr: 0.004198  loss: 0.2995 (0.4799)  loss_classifier: 0.0352 (0.0843)  loss_box_reg: 0.0696 (0.1019)  loss_mask: 0.1800 (0.2781)  loss_objectness: 0.0030 (0.0036)  loss_rpn_box_reg: 0.0053 (0.0119)  time: 0.6140  data: 0.0268  max mem: 5635
# Epoch: [0]  [260/300]  eta: 0:00:24  lr: 0.004365  loss: 0.2739 (0.4726)  loss_classifier: 0.0272 (0.0824)  loss_box_reg: 0.0611 (0.1006)  loss_mask: 0.1603 (0.2742)  loss_objectness: 0.0024 (0.0036)  loss_rpn_box_reg: 0.0039 (0.0119)  time: 0.6262  data: 0.0281  max mem: 5635
# Epoch: [0]  [270/300]  eta: 0:00:18  lr: 0.004532  loss: 0.2922 (0.4684)  loss_classifier: 0.0272 (0.0812)  loss_box_reg: 0.0662 (0.1004)  loss_mask: 0.1775 (0.2713)  loss_objectness: 0.0014 (0.0036)  loss_rpn_box_reg: 0.0068 (0.0118)  time: 0.6294  data: 0.0286  max mem: 5635
# Epoch: [0]  [280/300]  eta: 0:00:12  lr: 0.004699  loss: 0.2809 (0.4633)  loss_classifier: 0.0272 (0.0793)  loss_box_reg: 0.0640 (0.0991)  loss_mask: 0.1927 (0.2695)  loss_objectness: 0.0012 (0.0035)  loss_rpn_box_reg: 0.0108 (0.0119)  time: 0.6129  data: 0.0260  max mem: 5635
# Epoch: [0]  [290/300]  eta: 0:00:06  lr: 0.004866  loss: 0.2725 (0.4557)  loss_classifier: 0.0266 (0.0775)  loss_box_reg: 0.0533 (0.0978)  loss_mask: 0.1546 (0.2651)  loss_objectness: 0.0012 (0.0034)  loss_rpn_box_reg: 0.0090 (0.0118)  time: 0.6180  data: 0.0243  max mem: 5635
# Epoch: [0]  [299/300]  eta: 0:00:00  lr: 0.005000  loss: 0.2192 (0.4489)  loss_classifier: 0.0238 (0.0759)  loss_box_reg: 0.0498 (0.0964)  loss_mask: 0.1318 (0.2614)  loss_objectness: 0.0005 (0.0034)  loss_rpn_box_reg: 0.0062 (0.0117)  time: 0.6304  data: 0.0255  max mem: 5635
# Epoch: [0] Total time: 0:03:06 (0.6214 s / it)
# creating index...
# index created!
# Test:  [  0/200]  eta: 0:00:36  model_time: 0.1678 (0.1678)  evaluator_time: 0.0042 (0.0042)  time: 0.1836  data: 0.0111  max mem: 5635
# Test:  [100/200]  eta: 0:00:13  model_time: 0.1263 (0.1222)  evaluator_time: 0.0029 (0.0029)  time: 0.1385  data: 0.0112  max mem: 5635
# Test:  [199/200]  eta: 0:00:00  model_time: 0.1246 (0.1233)  evaluator_time: 0.0030 (0.0030)  time: 0.1418  data: 0.0146  max mem: 5635
# Test: Total time: 0:00:27 (0.1391 s / it)
# Averaged stats: model_time: 0.1246 (0.1233)  evaluator_time: 0.0030 (0.0030)
# Accumulating evaluation results...
# DONE (t=0.04s).
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.554
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.963
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.585
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.459
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.582
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.572
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.633
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.633
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.519
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.656
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.666
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.938
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.784
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.491
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.701
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.663
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.728
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.728
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.638
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.746
# Epoch 1
# Epoch: [1]  [  0/300]  eta: 0:02:48  lr: 0.005000  loss: 0.2750 (0.2750)  loss_classifier: 0.0283 (0.0283)  loss_box_reg: 0.0510 (0.0510)  loss_mask: 0.1894 (0.1894)  loss_objectness: 0.0020 (0.0020)  loss_rpn_box_reg: 0.0043 (0.0043)  time: 0.5633  data: 0.0267  max mem: 5635
# Epoch: [1]  [ 10/300]  eta: 0:03:07  lr: 0.005000  loss: 0.2656 (0.3138)  loss_classifier: 0.0263 (0.0334)  loss_box_reg: 0.0537 (0.0679)  loss_mask: 0.1770 (0.2002)  loss_objectness: 0.0020 (0.0027)  loss_rpn_box_reg: 0.0074 (0.0097)  time: 0.6455  data: 0.0265  max mem: 5635
# Epoch: [1]  [ 20/300]  eta: 0:02:59  lr: 0.005000  loss: 0.2462 (0.2977)  loss_classifier: 0.0258 (0.0332)  loss_box_reg: 0.0522 (0.0612)  loss_mask: 0.1505 (0.1924)  loss_objectness: 0.0020 (0.0026)  loss_rpn_box_reg: 0.0068 (0.0083)  time: 0.6453  data: 0.0252  max mem: 5635
# Epoch: [1]  [ 30/300]  eta: 0:02:48  lr: 0.005000  loss: 0.2655 (0.2857)  loss_classifier: 0.0263 (0.0311)  loss_box_reg: 0.0505 (0.0604)  loss_mask: 0.1505 (0.1784)  loss_objectness: 0.0024 (0.0032)  loss_rpn_box_reg: 0.0071 (0.0125)  time: 0.6127  data: 0.0230  max mem: 5635
# Epoch: [1]  [ 40/300]  eta: 0:02:42  lr: 0.005000  loss: 0.2618 (0.2879)  loss_classifier: 0.0263 (0.0328)  loss_box_reg: 0.0481 (0.0637)  loss_mask: 0.1296 (0.1751)  loss_objectness: 0.0024 (0.0031)  loss_rpn_box_reg: 0.0105 (0.0131)  time: 0.6061  data: 0.0245  max mem: 5635
# Epoch: [1]  [ 50/300]  eta: 0:02:36  lr: 0.005000  loss: 0.2083 (0.2818)  loss_classifier: 0.0180 (0.0307)  loss_box_reg: 0.0438 (0.0602)  loss_mask: 0.1222 (0.1734)  loss_objectness: 0.0015 (0.0030)  loss_rpn_box_reg: 0.0100 (0.0146)  time: 0.6279  data: 0.0273  max mem: 5635
# Epoch: [1]  [ 60/300]  eta: 0:02:30  lr: 0.005000  loss: 0.2951 (0.3008)  loss_classifier: 0.0245 (0.0315)  loss_box_reg: 0.0443 (0.0612)  loss_mask: 0.1755 (0.1904)  loss_objectness: 0.0014 (0.0035)  loss_rpn_box_reg: 0.0113 (0.0142)  time: 0.6351  data: 0.0261  max mem: 5635
# Epoch: [1]  [ 70/300]  eta: 0:02:24  lr: 0.005000  loss: 0.3613 (0.3077)  loss_classifier: 0.0280 (0.0315)  loss_box_reg: 0.0538 (0.0611)  loss_mask: 0.2400 (0.1978)  loss_objectness: 0.0026 (0.0035)  loss_rpn_box_reg: 0.0098 (0.0138)  time: 0.6270  data: 0.0235  max mem: 5635
# Epoch: [1]  [ 80/300]  eta: 0:02:16  lr: 0.005000  loss: 0.2689 (0.3072)  loss_classifier: 0.0280 (0.0318)  loss_box_reg: 0.0511 (0.0602)  loss_mask: 0.1578 (0.1982)  loss_objectness: 0.0029 (0.0036)  loss_rpn_box_reg: 0.0062 (0.0134)  time: 0.6038  data: 0.0239  max mem: 5635
# Epoch: [1]  [ 90/300]  eta: 0:02:11  lr: 0.005000  loss: 0.2455 (0.3140)  loss_classifier: 0.0248 (0.0325)  loss_box_reg: 0.0466 (0.0618)  loss_mask: 0.1469 (0.2032)  loss_objectness: 0.0027 (0.0035)  loss_rpn_box_reg: 0.0053 (0.0131)  time: 0.6303  data: 0.0267  max mem: 5635
# Epoch: [1]  [100/300]  eta: 0:02:04  lr: 0.005000  loss: 0.2732 (0.3178)  loss_classifier: 0.0293 (0.0341)  loss_box_reg: 0.0466 (0.0634)  loss_mask: 0.1663 (0.2035)  loss_objectness: 0.0027 (0.0035)  loss_rpn_box_reg: 0.0054 (0.0133)  time: 0.6374  data: 0.0277  max mem: 5635
# Epoch: [1]  [110/300]  eta: 0:01:58  lr: 0.005000  loss: 0.2806 (0.3168)  loss_classifier: 0.0344 (0.0349)  loss_box_reg: 0.0660 (0.0647)  loss_mask: 0.1633 (0.2008)  loss_objectness: 0.0022 (0.0036)  loss_rpn_box_reg: 0.0053 (0.0128)  time: 0.6229  data: 0.0292  max mem: 5635
# Epoch: [1]  [120/300]  eta: 0:01:52  lr: 0.005000  loss: 0.2831 (0.3155)  loss_classifier: 0.0321 (0.0344)  loss_box_reg: 0.0577 (0.0649)  loss_mask: 0.1744 (0.2000)  loss_objectness: 0.0020 (0.0034)  loss_rpn_box_reg: 0.0062 (0.0128)  time: 0.6267  data: 0.0287  max mem: 5635
# Epoch: [1]  [130/300]  eta: 0:01:46  lr: 0.005000  loss: 0.2648 (0.3105)  loss_classifier: 0.0259 (0.0340)  loss_box_reg: 0.0513 (0.0647)  loss_mask: 0.1429 (0.1956)  loss_objectness: 0.0017 (0.0035)  loss_rpn_box_reg: 0.0076 (0.0126)  time: 0.6238  data: 0.0282  max mem: 5635
# Epoch: [1]  [140/300]  eta: 0:01:39  lr: 0.005000  loss: 0.1917 (0.3029)  loss_classifier: 0.0196 (0.0330)  loss_box_reg: 0.0431 (0.0630)  loss_mask: 0.1077 (0.1906)  loss_objectness: 0.0015 (0.0034)  loss_rpn_box_reg: 0.0074 (0.0127)  time: 0.6079  data: 0.0275  max mem: 5635
# Epoch: [1]  [150/300]  eta: 0:01:33  lr: 0.005000  loss: 0.2155 (0.2993)  loss_classifier: 0.0219 (0.0330)  loss_box_reg: 0.0486 (0.0632)  loss_mask: 0.1118 (0.1870)  loss_objectness: 0.0012 (0.0033)  loss_rpn_box_reg: 0.0067 (0.0127)  time: 0.6070  data: 0.0253  max mem: 5635
# Epoch: [1]  [160/300]  eta: 0:01:27  lr: 0.005000  loss: 0.2634 (0.2988)  loss_classifier: 0.0293 (0.0333)  loss_box_reg: 0.0624 (0.0639)  loss_mask: 0.1323 (0.1860)  loss_objectness: 0.0012 (0.0032)  loss_rpn_box_reg: 0.0061 (0.0124)  time: 0.6230  data: 0.0256  max mem: 5635
# Epoch: [1]  [170/300]  eta: 0:01:20  lr: 0.005000  loss: 0.3063 (0.3057)  loss_classifier: 0.0347 (0.0343)  loss_box_reg: 0.0719 (0.0657)  loss_mask: 0.1525 (0.1903)  loss_objectness: 0.0013 (0.0033)  loss_rpn_box_reg: 0.0049 (0.0121)  time: 0.6059  data: 0.0274  max mem: 5635
# Epoch: [1]  [180/300]  eta: 0:01:14  lr: 0.005000  loss: 0.3572 (0.3094)  loss_classifier: 0.0400 (0.0343)  loss_box_reg: 0.0616 (0.0653)  loss_mask: 0.2225 (0.1942)  loss_objectness: 0.0025 (0.0033)  loss_rpn_box_reg: 0.0063 (0.0123)  time: 0.6191  data: 0.0273  max mem: 5635
# Epoch: [1]  [190/300]  eta: 0:01:08  lr: 0.005000  loss: 0.2860 (0.3053)  loss_classifier: 0.0236 (0.0336)  loss_box_reg: 0.0429 (0.0641)  loss_mask: 0.2094 (0.1920)  loss_objectness: 0.0025 (0.0033)  loss_rpn_box_reg: 0.0092 (0.0123)  time: 0.6203  data: 0.0237  max mem: 5635
# Epoch: [1]  [200/300]  eta: 0:01:02  lr: 0.005000  loss: 0.2449 (0.3115)  loss_classifier: 0.0221 (0.0343)  loss_box_reg: 0.0398 (0.0644)  loss_mask: 0.1565 (0.1975)  loss_objectness: 0.0011 (0.0033)  loss_rpn_box_reg: 0.0067 (0.0121)  time: 0.6101  data: 0.0246  max mem: 5635
# Epoch: [1]  [210/300]  eta: 0:00:55  lr: 0.005000  loss: 0.2449 (0.3088)  loss_classifier: 0.0218 (0.0339)  loss_box_reg: 0.0451 (0.0640)  loss_mask: 0.1584 (0.1955)  loss_objectness: 0.0008 (0.0033)  loss_rpn_box_reg: 0.0070 (0.0121)  time: 0.6287  data: 0.0271  max mem: 5635
# Epoch: [1]  [220/300]  eta: 0:00:49  lr: 0.005000  loss: 0.2354 (0.3064)  loss_classifier: 0.0197 (0.0334)  loss_box_reg: 0.0451 (0.0633)  loss_mask: 0.1374 (0.1945)  loss_objectness: 0.0008 (0.0032)  loss_rpn_box_reg: 0.0075 (0.0119)  time: 0.6284  data: 0.0279  max mem: 5635
# Epoch: [1]  [230/300]  eta: 0:00:43  lr: 0.005000  loss: 0.2380 (0.3086)  loss_classifier: 0.0233 (0.0332)  loss_box_reg: 0.0415 (0.0623)  loss_mask: 0.1491 (0.1976)  loss_objectness: 0.0016 (0.0033)  loss_rpn_box_reg: 0.0087 (0.0123)  time: 0.6174  data: 0.0268  max mem: 5635
# Epoch: [1]  [240/300]  eta: 0:00:37  lr: 0.005000  loss: 0.2380 (0.3094)  loss_classifier: 0.0241 (0.0328)  loss_box_reg: 0.0433 (0.0616)  loss_mask: 0.1618 (0.1995)  loss_objectness: 0.0025 (0.0033)  loss_rpn_box_reg: 0.0095 (0.0122)  time: 0.6086  data: 0.0252  max mem: 5635
# Epoch: [1]  [250/300]  eta: 0:00:31  lr: 0.005000  loss: 0.2873 (0.3085)  loss_classifier: 0.0240 (0.0326)  loss_box_reg: 0.0443 (0.0611)  loss_mask: 0.1816 (0.1993)  loss_objectness: 0.0025 (0.0033)  loss_rpn_box_reg: 0.0077 (0.0123)  time: 0.6138  data: 0.0248  max mem: 5635
# Epoch: [1]  [260/300]  eta: 0:00:24  lr: 0.005000  loss: 0.2384 (0.3059)  loss_classifier: 0.0212 (0.0322)  loss_box_reg: 0.0413 (0.0605)  loss_mask: 0.1755 (0.1976)  loss_objectness: 0.0018 (0.0033)  loss_rpn_box_reg: 0.0075 (0.0122)  time: 0.6214  data: 0.0251  max mem: 5635
# Epoch: [1]  [270/300]  eta: 0:00:18  lr: 0.005000  loss: 0.2162 (0.3037)  loss_classifier: 0.0262 (0.0323)  loss_box_reg: 0.0402 (0.0600)  loss_mask: 0.1197 (0.1960)  loss_objectness: 0.0016 (0.0033)  loss_rpn_box_reg: 0.0075 (0.0122)  time: 0.6120  data: 0.0266  max mem: 5635
# Epoch: [1]  [280/300]  eta: 0:00:12  lr: 0.005000  loss: 0.2164 (0.3016)  loss_classifier: 0.0280 (0.0321)  loss_box_reg: 0.0450 (0.0596)  loss_mask: 0.1228 (0.1944)  loss_objectness: 0.0011 (0.0032)  loss_rpn_box_reg: 0.0070 (0.0122)  time: 0.6198  data: 0.0260  max mem: 5635
# Epoch: [1]  [290/300]  eta: 0:00:06  lr: 0.005000  loss: 0.2436 (0.3007)  loss_classifier: 0.0276 (0.0320)  loss_box_reg: 0.0446 (0.0592)  loss_mask: 0.1286 (0.1941)  loss_objectness: 0.0015 (0.0032)  loss_rpn_box_reg: 0.0070 (0.0121)  time: 0.6372  data: 0.0245  max mem: 5635
# Epoch: [1]  [299/300]  eta: 0:00:00  lr: 0.005000  loss: 0.2333 (0.2979)  loss_classifier: 0.0276 (0.0320)  loss_box_reg: 0.0447 (0.0589)  loss_mask: 0.1228 (0.1918)  loss_objectness: 0.0015 (0.0032)  loss_rpn_box_reg: 0.0068 (0.0120)  time: 0.6338  data: 0.0248  max mem: 5635
# Epoch: [1] Total time: 0:03:06 (0.6218 s / it)
# creating index...
# index created!
# Test:  [  0/200]  eta: 0:00:39  model_time: 0.1793 (0.1793)  evaluator_time: 0.0041 (0.0041)  time: 0.1951  data: 0.0113  max mem: 5635
# Test:  [100/200]  eta: 0:00:14  model_time: 0.1316 (0.1278)  evaluator_time: 0.0032 (0.0032)  time: 0.1451  data: 0.0121  max mem: 5635
# Test:  [199/200]  eta: 0:00:00  model_time: 0.1330 (0.1303)  evaluator_time: 0.0043 (0.0037)  time: 0.1546  data: 0.0143  max mem: 5635
# Test: Total time: 0:00:29 (0.1470 s / it)
# Averaged stats: model_time: 0.1330 (0.1303)  evaluator_time: 0.0043 (0.0037)
# Accumulating evaluation results...
# DONE (t=0.05s).
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.621
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.933
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.751
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.549
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.641
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.641
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.707
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.707
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.620
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.727
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.641
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.916
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.715
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.492
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.676
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.664
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.734
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.734
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.653
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.752
# Epoch 2
# Epoch: [2]  [  0/300]  eta: 0:03:00  lr: 0.005000  loss: 0.3708 (0.3708)  loss_classifier: 0.0682 (0.0682)  loss_box_reg: 0.1109 (0.1109)  loss_mask: 0.1855 (0.1855)  loss_objectness: 0.0009 (0.0009)  loss_rpn_box_reg: 0.0053 (0.0053)  time: 0.6025  data: 0.0237  max mem: 5635
# Epoch: [2]  [ 10/300]  eta: 0:03:00  lr: 0.005000  loss: 0.2957 (0.4192)  loss_classifier: 0.0281 (0.0362)  loss_box_reg: 0.0667 (0.0661)  loss_mask: 0.1909 (0.3052)  loss_objectness: 0.0014 (0.0021)  loss_rpn_box_reg: 0.0077 (0.0096)  time: 0.6234  data: 0.0283  max mem: 5635
# Epoch: [2]  [ 20/300]  eta: 0:02:57  lr: 0.005000  loss: 0.2957 (0.3863)  loss_classifier: 0.0245 (0.0392)  loss_box_reg: 0.0470 (0.0656)  loss_mask: 0.1948 (0.2713)  loss_objectness: 0.0018 (0.0020)  loss_rpn_box_reg: 0.0073 (0.0082)  time: 0.6352  data: 0.0279  max mem: 5635
# Epoch: [2]  [ 30/300]  eta: 0:02:52  lr: 0.005000  loss: 0.2585 (0.3480)  loss_classifier: 0.0283 (0.0384)  loss_box_reg: 0.0449 (0.0587)  loss_mask: 0.1774 (0.2395)  loss_objectness: 0.0016 (0.0022)  loss_rpn_box_reg: 0.0062 (0.0091)  time: 0.6451  data: 0.0253  max mem: 5635
# Epoch: [2]  [ 40/300]  eta: 0:02:42  lr: 0.005000  loss: 0.2387 (0.3311)  loss_classifier: 0.0300 (0.0361)  loss_box_reg: 0.0446 (0.0583)  loss_mask: 0.1454 (0.2258)  loss_objectness: 0.0016 (0.0024)  loss_rpn_box_reg: 0.0053 (0.0085)  time: 0.6175  data: 0.0251  max mem: 5635
# Epoch: [2]  [ 50/300]  eta: 0:02:36  lr: 0.005000  loss: 0.2317 (0.3270)  loss_classifier: 0.0281 (0.0347)  loss_box_reg: 0.0405 (0.0580)  loss_mask: 0.1554 (0.2234)  loss_objectness: 0.0019 (0.0025)  loss_rpn_box_reg: 0.0039 (0.0085)  time: 0.6057  data: 0.0293  max mem: 5635
# Epoch: [2]  [ 60/300]  eta: 0:02:29  lr: 0.005000  loss: 0.2537 (0.3209)  loss_classifier: 0.0223 (0.0333)  loss_box_reg: 0.0396 (0.0568)  loss_mask: 0.1628 (0.2178)  loss_objectness: 0.0020 (0.0027)  loss_rpn_box_reg: 0.0082 (0.0103)  time: 0.6225  data: 0.0277  max mem: 5635
# Epoch: [2]  [ 70/300]  eta: 0:02:24  lr: 0.005000  loss: 0.2712 (0.3191)  loss_classifier: 0.0229 (0.0322)  loss_box_reg: 0.0430 (0.0565)  loss_mask: 0.1816 (0.2160)  loss_objectness: 0.0029 (0.0028)  loss_rpn_box_reg: 0.0133 (0.0116)  time: 0.6318  data: 0.0246  max mem: 5635
# Epoch: [2]  [ 80/300]  eta: 0:02:18  lr: 0.005000  loss: 0.2965 (0.3178)  loss_classifier: 0.0240 (0.0319)  loss_box_reg: 0.0441 (0.0557)  loss_mask: 0.1877 (0.2148)  loss_objectness: 0.0027 (0.0029)  loss_rpn_box_reg: 0.0148 (0.0125)  time: 0.6402  data: 0.0260  max mem: 5635
# Epoch: [2]  [ 90/300]  eta: 0:02:11  lr: 0.005000  loss: 0.2318 (0.3058)  loss_classifier: 0.0220 (0.0305)  loss_box_reg: 0.0425 (0.0545)  loss_mask: 0.1366 (0.2057)  loss_objectness: 0.0021 (0.0029)  loss_rpn_box_reg: 0.0071 (0.0122)  time: 0.6175  data: 0.0245  max mem: 5635
# Epoch: [2]  [100/300]  eta: 0:02:04  lr: 0.005000  loss: 0.1927 (0.2983)  loss_classifier: 0.0201 (0.0305)  loss_box_reg: 0.0429 (0.0548)  loss_mask: 0.1176 (0.1981)  loss_objectness: 0.0011 (0.0028)  loss_rpn_box_reg: 0.0061 (0.0120)  time: 0.6073  data: 0.0252  max mem: 5635
# Epoch: [2]  [110/300]  eta: 0:01:58  lr: 0.005000  loss: 0.2100 (0.2943)  loss_classifier: 0.0201 (0.0295)  loss_box_reg: 0.0433 (0.0540)  loss_mask: 0.1421 (0.1964)  loss_objectness: 0.0010 (0.0028)  loss_rpn_box_reg: 0.0063 (0.0116)  time: 0.6170  data: 0.0250  max mem: 5635
# Epoch: [2]  [120/300]  eta: 0:01:52  lr: 0.005000  loss: 0.2193 (0.2903)  loss_classifier: 0.0201 (0.0289)  loss_box_reg: 0.0433 (0.0534)  loss_mask: 0.1364 (0.1937)  loss_objectness: 0.0009 (0.0028)  loss_rpn_box_reg: 0.0061 (0.0115)  time: 0.6146  data: 0.0230  max mem: 5635
# Epoch: [2]  [130/300]  eta: 0:01:46  lr: 0.005000  loss: 0.2268 (0.2870)  loss_classifier: 0.0231 (0.0288)  loss_box_reg: 0.0439 (0.0536)  loss_mask: 0.1257 (0.1903)  loss_objectness: 0.0018 (0.0029)  loss_rpn_box_reg: 0.0070 (0.0115)  time: 0.6242  data: 0.0245  max mem: 5635
# Epoch: [2]  [140/300]  eta: 0:01:40  lr: 0.005000  loss: 0.2019 (0.2811)  loss_classifier: 0.0226 (0.0287)  loss_box_reg: 0.0449 (0.0534)  loss_mask: 0.1144 (0.1848)  loss_objectness: 0.0016 (0.0028)  loss_rpn_box_reg: 0.0070 (0.0115)  time: 0.6445  data: 0.0248  max mem: 5635
# Epoch: [2]  [150/300]  eta: 0:01:33  lr: 0.005000  loss: 0.2019 (0.2758)  loss_classifier: 0.0228 (0.0284)  loss_box_reg: 0.0396 (0.0528)  loss_mask: 0.1150 (0.1805)  loss_objectness: 0.0012 (0.0028)  loss_rpn_box_reg: 0.0056 (0.0114)  time: 0.6274  data: 0.0263  max mem: 5635
# Epoch: [2]  [160/300]  eta: 0:01:27  lr: 0.005000  loss: 0.2056 (0.2739)  loss_classifier: 0.0264 (0.0283)  loss_box_reg: 0.0368 (0.0528)  loss_mask: 0.1191 (0.1785)  loss_objectness: 0.0018 (0.0028)  loss_rpn_box_reg: 0.0060 (0.0114)  time: 0.6061  data: 0.0282  max mem: 5635
# Epoch: [2]  [170/300]  eta: 0:01:20  lr: 0.005000  loss: 0.2119 (0.2712)  loss_classifier: 0.0190 (0.0277)  loss_box_reg: 0.0422 (0.0525)  loss_mask: 0.1318 (0.1768)  loss_objectness: 0.0011 (0.0027)  loss_rpn_box_reg: 0.0074 (0.0114)  time: 0.6105  data: 0.0263  max mem: 5635
# Epoch: [2]  [180/300]  eta: 0:01:14  lr: 0.005000  loss: 0.2141 (0.2707)  loss_classifier: 0.0190 (0.0280)  loss_box_reg: 0.0496 (0.0532)  loss_mask: 0.1324 (0.1754)  loss_objectness: 0.0011 (0.0027)  loss_rpn_box_reg: 0.0099 (0.0114)  time: 0.6375  data: 0.0240  max mem: 5635
# Epoch: [2]  [190/300]  eta: 0:01:08  lr: 0.005000  loss: 0.2371 (0.2720)  loss_classifier: 0.0236 (0.0278)  loss_box_reg: 0.0508 (0.0528)  loss_mask: 0.1459 (0.1775)  loss_objectness: 0.0017 (0.0027)  loss_rpn_box_reg: 0.0080 (0.0114)  time: 0.6270  data: 0.0230  max mem: 5635
# Epoch: [2]  [200/300]  eta: 0:01:02  lr: 0.005000  loss: 0.2484 (0.2729)  loss_classifier: 0.0212 (0.0279)  loss_box_reg: 0.0508 (0.0529)  loss_mask: 0.1590 (0.1779)  loss_objectness: 0.0023 (0.0028)  loss_rpn_box_reg: 0.0061 (0.0115)  time: 0.6124  data: 0.0215  max mem: 5635
# Epoch: [2]  [210/300]  eta: 0:00:55  lr: 0.005000  loss: 0.2325 (0.2718)  loss_classifier: 0.0219 (0.0281)  loss_box_reg: 0.0585 (0.0531)  loss_mask: 0.1385 (0.1767)  loss_objectness: 0.0012 (0.0027)  loss_rpn_box_reg: 0.0078 (0.0113)  time: 0.6075  data: 0.0227  max mem: 5635
# Epoch: [2]  [220/300]  eta: 0:00:49  lr: 0.005000  loss: 0.2219 (0.2689)  loss_classifier: 0.0209 (0.0278)  loss_box_reg: 0.0479 (0.0527)  loss_mask: 0.1242 (0.1745)  loss_objectness: 0.0007 (0.0027)  loss_rpn_box_reg: 0.0052 (0.0112)  time: 0.5949  data: 0.0249  max mem: 5635
# Epoch: [2]  [230/300]  eta: 0:00:43  lr: 0.005000  loss: 0.2186 (0.2668)  loss_classifier: 0.0195 (0.0274)  loss_box_reg: 0.0380 (0.0521)  loss_mask: 0.1233 (0.1731)  loss_objectness: 0.0010 (0.0027)  loss_rpn_box_reg: 0.0064 (0.0116)  time: 0.6086  data: 0.0238  max mem: 5635
# Epoch: [2]  [240/300]  eta: 0:00:37  lr: 0.005000  loss: 0.1926 (0.2661)  loss_classifier: 0.0179 (0.0282)  loss_box_reg: 0.0369 (0.0524)  loss_mask: 0.1061 (0.1711)  loss_objectness: 0.0009 (0.0027)  loss_rpn_box_reg: 0.0103 (0.0117)  time: 0.6497  data: 0.0241  max mem: 5635
# Epoch: [2]  [250/300]  eta: 0:00:31  lr: 0.005000  loss: 0.1861 (0.2633)  loss_classifier: 0.0202 (0.0281)  loss_box_reg: 0.0393 (0.0519)  loss_mask: 0.1048 (0.1689)  loss_objectness: 0.0011 (0.0027)  loss_rpn_box_reg: 0.0095 (0.0117)  time: 0.6642  data: 0.0241  max mem: 5635
# Epoch: [2]  [260/300]  eta: 0:00:24  lr: 0.005000  loss: 0.1885 (0.2631)  loss_classifier: 0.0215 (0.0282)  loss_box_reg: 0.0346 (0.0520)  loss_mask: 0.1167 (0.1687)  loss_objectness: 0.0012 (0.0026)  loss_rpn_box_reg: 0.0072 (0.0116)  time: 0.6151  data: 0.0226  max mem: 5635
# Epoch: [2]  [270/300]  eta: 0:00:18  lr: 0.005000  loss: 0.2137 (0.2638)  loss_classifier: 0.0268 (0.0286)  loss_box_reg: 0.0436 (0.0525)  loss_mask: 0.1276 (0.1686)  loss_objectness: 0.0007 (0.0026)  loss_rpn_box_reg: 0.0063 (0.0115)  time: 0.6038  data: 0.0232  max mem: 5635
# Epoch: [2]  [280/300]  eta: 0:00:12  lr: 0.005000  loss: 0.2322 (0.2629)  loss_classifier: 0.0284 (0.0286)  loss_box_reg: 0.0516 (0.0523)  loss_mask: 0.1491 (0.1681)  loss_objectness: 0.0008 (0.0026)  loss_rpn_box_reg: 0.0039 (0.0114)  time: 0.6240  data: 0.0239  max mem: 5635
# Epoch: [2]  [290/300]  eta: 0:00:06  lr: 0.005000  loss: 0.2200 (0.2641)  loss_classifier: 0.0234 (0.0287)  loss_box_reg: 0.0442 (0.0522)  loss_mask: 0.1424 (0.1691)  loss_objectness: 0.0018 (0.0026)  loss_rpn_box_reg: 0.0065 (0.0115)  time: 0.6191  data: 0.0239  max mem: 5635
# Epoch: [2]  [299/300]  eta: 0:00:00  lr: 0.005000  loss: 0.2200 (0.2654)  loss_classifier: 0.0234 (0.0287)  loss_box_reg: 0.0442 (0.0523)  loss_mask: 0.1375 (0.1704)  loss_objectness: 0.0018 (0.0026)  loss_rpn_box_reg: 0.0076 (0.0114)  time: 0.6137  data: 0.0232  max mem: 5635
# Epoch: [2] Total time: 0:03:06 (0.6224 s / it)
# creating index...
# index created!
# Test:  [  0/200]  eta: 0:00:36  model_time: 0.1703 (0.1703)  evaluator_time: 0.0028 (0.0028)  time: 0.1841  data: 0.0106  max mem: 5635
# Test:  [100/200]  eta: 0:00:13  model_time: 0.1227 (0.1222)  evaluator_time: 0.0028 (0.0029)  time: 0.1364  data: 0.0102  max mem: 5635
# Test:  [199/200]  eta: 0:00:00  model_time: 0.1244 (0.1235)  evaluator_time: 0.0040 (0.0032)  time: 0.1420  data: 0.0128  max mem: 5635
# Test: Total time: 0:00:27 (0.1378 s / it)
# Averaged stats: model_time: 0.1244 (0.1235)  evaluator_time: 0.0040 (0.0032)
# Accumulating evaluation results...
# DONE (t=0.05s).
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.588
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.889
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.724
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.555
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.604
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.581
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.703
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.664
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.713
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.634
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.870
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.724
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.536
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.658
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.629
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.739
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.743
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.693
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.754

# %% [markdown]
# We'll generate the output for the same image, but this time with the new finetuned model.

# %%
img, target = dataset_test[1]

# put the model in evaluation mode
model_p3.eval()
with torch.no_grad():
    prediction = model_p3([img.to(device)])

Image.fromarray(img.mul(255).permute(1, 2, 0).byte().numpy())
# Out:
# <PIL.Image.Image image mode=RGB size=259x194>

# %% [markdown]
# Here's the predicted image.

# %%
Image.fromarray(prediction[0]['masks'][0, 0].mul(255).byte().cpu().numpy())
# Out:
# <PIL.Image.Image image mode=L size=259x194>

# %% [markdown]
# ## Question 10 [5%]
#
# Does this model perform better than the trained model after Q7 ? How do you campare these models ? Explain why the model performs better than the other model.

# %% [markdown]
# #### Answer :
# The new model has led to a reduction in losses across all categories, with a notable improvement in mask prediction.
# The evaluation metrics post-training show a considerable improvement, indicating enhanced accuracy and reliability of the model.
#
# It's clear that the new model performed better, as evidenced by the improved performance metrics. This suggests that the model is now better at generalizing and making accurate predictions, particularly in terms of mask prediction.
#
# Before:
#
# Epoch 0: The initial losses are relatively high, with the loss_mask being the highest. This suggests the model initially struggled more with mask prediction.
#
# Epoch 1: There is a noticeable reduction in losses across all categories, indicating that the model is learning and improving its performance.
#
# Epoch 2: Further reduction in losses, showing continued learning and improvement.
#
# Evaluation Metrics (IoU metric: bbox and segm): The Average Precision (AP) and Average Recall (AR) across different IoUs (Intersection over Union) and areas show the model's performance after the initial training phase. The AP and AR values are moderate, indicating a fair performance but with room for improvement.
#
# After:
#
# Epoch 0: The losses start at a lower point compared to the 'before' training scenario. This suggests that the modifications or continued training has had a positive effect.
#
# Epoch 1: There's a further reduction in losses, with loss_mask still being the highest but lower than the initial 'before training' values.
#
# Epoch 2: Continued reduction in losses, with a more noticeable decrease in loss_mask, indicating improved mask prediction capabilities.
#
# Evaluation Metrics (IoU metric: bbox and segm): There is a significant improvement in AP and AR values across different IoUs and areas. The model shows better accuracy and recall, suggesting that the changes made have positively impacted its performance.

# %% [markdown]
# ## Question 11 [10 %]
#
# Discuss any 4 advantage of using CONV layers over FC/Dense layers?

# %% [markdown]
# #### Answer :
# Parameter Efficiency:
#
# CONV layers are significantly more parameter-efficient compared to FC layers. In a CONV layer, weights are shared across the input image through the convolution operation, meaning the same filter (set of weights) is used to scan the entire image. This results in a much smaller number of parameters, which not only reduces the memory usage but also helps to alleviate overfitting.
#
# Spatial Hierarchies of Features:
#
# Convolutional layers are adept at capturing the spatial hierarchies in images. Lower layers might capture edges or textures, while deeper layers can learn more complex patterns or objects. This is because the convolution operation preserves the spatial relationship between pixels by learning image features using small squares of input data. FC layers, on the other hand, do not leverage spatial hierarchies, as they treat input data as a flat vector.
#
# Translation Invariance:
#
# Due to the nature of the convolution operation and pooling layers often used with CONV layers, convolutional neural networks (CNNs) are more translation-invariant compared to models with only FC layers. This means that a CNN can recognize an object in an image, no matter where it is located in the picture. FC layers lack this property because each neuron is connected to every input, leading to a strict dependence on the position of features in the input space.
#
# Locality and Receptive Fields:
#
# CONV layers have local receptive fields, meaning each neuron in a CONV layer is connected to only a small region of the input. This allows the network to capture local features (like edges in an image) before integrating them into more global features in deeper layers. FC layers do not have this property; each neuron in an FC layer is connected to every input feature, which makes them less effective in capturing local patterns within input data.

# %% [markdown]
# # 4. Extra Credit Questions

# %% [markdown]
# ## Question 12 [10 points]
#
# Can fully convolutional networks (FCN) be used for object detection? In Mask-RCNN we have 3 branches — mask, classification, and bounding box regression — out of which the last 2 have fully connected (FC) layers. Can this entire pipeline be replaced by a fully convolutional network? If possible, discuss any 2 networks to support your claim explaining their architecture.

# %% [markdown]
# #### Answer :
# Fully Convolutional Networks (FCN) can indeed be used for object detection, and there are architectures that have successfully replaced parts of the pipeline traditionally relying on Fully Connected (FC) layers with convolutional layers. This approach offers several benefits, including the ability to handle input images of various sizes and improved efficiency in terms of parameter usage. Here are two notable examples of such architectures:
# 1. YOLO (You Only Look Once)
#
#     Architecture: YOLO is a groundbreaking object detection system that reframes object detection as a single regression problem, straight from image pixels to bounding box coordinates and class probabilities. It divides the input image into a grid, and each grid cell predicts a certain number of bounding boxes and class probabilities for those boxes. The key aspect here is that YOLO uses convolutional layers not only for feature extraction but also for predicting bounding boxes and class probabilities. This makes it a fully convolutional network.
#
#     Advantages: YOLO's end-to-end training and inference are extremely fast compared to region-proposal-based methods like R-CNN. Its unified architecture also tends to generalize better to new domains or unexpected inputs. YOLO's convolutional approach to bounding box prediction allows it to learn more complex features and spatial hierarchies, enhancing its detection capabilities.
#
# 2. SSD (Single Shot MultiBox Detector)
#
#     Architecture: SSD, like YOLO, is another one-stage detector that uses a fully convolutional network. It discretizes the output space of bounding boxes into a set of default boxes over different aspect ratios and scales per feature map location. During prediction, the network generates scores for the presence of each object category in each default box and adjusts the box to better match the object shape. The network combines predictions from multiple feature maps with different resolutions to naturally handle objects of various sizes.
#
#     Advantages: SSD's use of multiple feature maps with different resolutions allows it to handle a wide range of object sizes more effectively than YOLO, which relies on a single feature map. It's also faster than methods like Faster R-CNN, as it eliminates the need for a separate region proposal network.
#
# Replacing FC Layers in Mask R-CNN
#
# In the case of Mask R-CNN, replacing the FC layers in the classification and bounding box regression branches with convolutional layers is theoretically possible. This would involve adapting the network architecture to maintain spatial information throughout the network, potentially using techniques like spatial pyramid pooling or similar methods to handle varying input sizes and shapes. However, it's important to note that the effectiveness of such a modification would depend on the specific implementation and how well it integrates with the rest of the Mask R-CNN architecture. The challenge would be to maintain the high level of accuracy and robustness that Mask R-CNN offers, especially in its ability to precisely segment objects at a pixel level while also classifying them and predicting their bounding boxes.
